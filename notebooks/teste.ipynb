# %%
import os
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, SummaryIndex
from llama_index.core.node_parser import SentenceSplitter, SimpleNodeParser, TokenTextSplitter, TextSplitter
from llama_index.core.ingestion import IngestionPipeline
from llama_index.core.extractors import KeywordExtractor, TitleExtractor
from llama_index.core.schema import MetadataMode
from llama_index.llms.ollama import Ollama
import nest_asyncio

# %%
pentaho_file_path = '../data/fact_sales.xml'

# %%
documents = SimpleDirectoryReader(input_files=[pentaho_file_path]).load_data()

# %%
parser = SimpleNodeParser.from_defaults()
nodes = parser.get_nodes_from_documents(documents)

# %%
splitter = SentenceSplitter(chunk_size=1024, chunk_overlap=100)
pipeline = IngestionPipeline(transformations=[splitter])
nodes = pipeline.run(documents=documents)

# %%
# print(f"Total Nodes: {len(nodes)}")
# print(f"Listar conteúdo do node 0: {nodes[0].get_content(metadata_mode='all')}")

# %%
print(len(nodes))
# Out:
# 33

# %%
nest_asyncio.apply()

# %%
llm = Ollama(model="gemma2:2b", temperature=0.1, request_timeout=1800.0)

# %%
response = llm.complete("What is the capital of France?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 response = llm.complete("What is the capital of France?")
#       2 print(response)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:260, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     252 self.span_enter(
#     253     id_=id_,
#     254     bound_args=bound_args,
#    (...)
#     257     tags=tags,
#     258 )
#     259 try:
# --> 260     result = func(*args, **kwargs)
#     261 except BaseException as e:
#     262     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/llama_index/core/llms/callbacks.py:429, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
# ...

# %%
MetadataMode.EMBED
# Out:
# <MetadataMode.EMBED: 'embed'>

# %%
enrich_metadadata_pipeline = IngestionPipeline(
    transformations=[
        SentenceSplitter(chunk_size=1024, chunk_overlap=20),
        TitleExtractor(llm=llm, metadata_mode=MetadataMode.EMBED),
        KeywordExtractor(llm=llm, metadata_mode=MetadataMode.EMBED)
    ]
)
nodes = enrich_metadadata_pipeline.run(documents=documents)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[115], line 8
#       1 enrich_metadadata_pipeline = IngestionPipeline(
#       2     transformations=[
#       3         SentenceSplitter(chunk_size=1024, chunk_overlap=20),
#    (...)
#       6     ]
#       7 )
# ----> 8 nodes = enrich_metadadata_pipeline.run(documents=documents)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:260, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     252 self.span_enter(
#     253     id_=id_,
#     254     bound_args=bound_args,
#    (...)
#     257     tags=tags,
#     258 )
#     259 try:
# --> 260     result = func(*args, **kwargs)
#     261 except BaseException as e:
#     262     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# ...
