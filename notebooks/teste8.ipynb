# %%
import xml.etree.ElementTree as ET
import operator
import logging
from typing import Any, Dict, List, Tuple, TypedDict, Annotated
import pandas as pd
import pygraphviz as pgv
from langchain_ollama.llms import OllamaLLM
from langchain.prompts import PromptTemplate
from langchain.schema.runnable import RunnableSequence
from langgraph.graph import StateGraph
import os

# %%
pentaho_file_path = '../data/benef_transf.ktr'

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class AgentState(TypedDict):
    messages: Annotated[list[Any], operator.add]
    file_path: str
    root: ET.Element
    sequence: List[Tuple[str, str]]
    queries: List[Dict[str, str]]
    relations: pd.DataFrame
    documentation: str
    analysis_results: List[Dict[str, str]] 
    insert_update_info: List[Dict[str, Any]]

class Agent:
    def __init__(self, model: Any, tools: Any, file_path: str, system: str = "", max_tokens_per_part: int = 400):
        self.system = system
        self.file_path = file_path
        self.llm = model
        self.max_tokens_per_part = max_tokens_per_part
        self.graph = self._create_state_graph()
        ktr_filename = os.path.basename(file_path)
        self.markdown_filename = os.path.splitext(ktr_filename)[0] + ".md"        

    def _create_state_graph(self) -> StateGraph:
        graph = StateGraph(AgentState)

        graph.add_node("parse", self.parse_ktr_file)
        graph.add_node("extract_sequence", self.extract_execution_sequence)
        
        #graph.add_node("extract_sql", self.extract_sql_queries)
        graph.add_node("extract_sql", self.extract_queries_and_insert_update_info)
        
        graph.add_node("save_sql_to_files", self.save_sql_to_files)
        graph.add_node("analyze_sql_files_llm", self.analyze_sql_files_llm)
        graph.add_node("generate_markdown_llm", self.generate_markdown_llm)
        graph.add_node("create_graph", self.create_execution_graph)
        graph.add_node("export_markdown", self.export_markdown_to_file)        

        graph.add_edge("parse", "extract_sequence")
              
        graph.add_edge("extract_sequence", "extract_sql")
        graph.add_edge("extract_sql", "save_sql_to_files")
        graph.add_edge("save_sql_to_files", "analyze_sql_files_llm")
        graph.add_edge("analyze_sql_files_llm", "generate_markdown_llm")
        
        #graph.add_edge("extract_insert_update", "generate_markdown_llm")
        
        graph.add_edge("generate_markdown_llm", "create_graph")
        graph.add_edge("create_graph", "export_markdown")

        graph.set_entry_point("parse")
        return graph.compile()
    
    def save_sql_to_files(self, state: AgentState) -> AgentState:
        """Save each SQL query to a separate .sql file."""
        os.makedirs('sql_files', exist_ok=True)
        for idx, query in enumerate(state["queries"], start=1):
            file_name = f'sql_files/query_{idx}.sql'
            with open(file_name, 'w') as file:
                file.write(query['sql'])
            query['file_name'] = file_name  # Store the filename for later use

        return state    

    def parse_ktr_file(self, state: AgentState) -> AgentState:
        try:
            tree = ET.parse(state["file_path"])
            state["root"] = tree.getroot()
        except ET.ParseError as e:
            logging.error(f"Error parsing KTR file: {e}")
            raise
        return state

    def extract_execution_sequence(self, state: AgentState) -> AgentState:
        hops = []
        for hop in state["root"].findall('.//hop'):
            from_step = hop.find('from').text
            to_step = hop.find('to').text
            enabled = hop.find('enabled').text
            if enabled == 'Y':
                hops.append((from_step, to_step))
        
        state["sequence"] = hops
        return state    
 

    def extract_queries_and_insert_update_info(self, state: AgentState) -> AgentState:
        active_steps = set(step for seq in state["sequence"] for step in seq)
        steps = state["root"].findall(".//step")
        queries = []
        insert_update_info = []

        for step in steps:
            step_name = step.find("name").text
            step_type = step.find("type").text
            
            if step_name in active_steps:
                # Extraindo consultas SQL para passos do tipo 'TableInput' e 'DBJoin'
                if step_type in ['TableInput', 'DBJoin']:
                    sql_element = step.find("sql")
                    if sql_element is not None and sql_element.text:
                        queries.append({
                            "step_name": step_name,
                            "step_type": step_type,
                            "sql": sql_element.text
                        })
                
                # Extraindo informações para passos do tipo 'InsertUpdate'
                elif step_type == "InsertUpdate":
                    table_name = step.find('.//table').text if step.find('.//table') is not None else None
                    keys = step.findall('.//key')
                    key_columns = {key.find('name').text for key in keys if key.find('name') is not None}
                    values = step.findall('.//value')
                    
                    for value in values:
                        column_name = value.find('rename').text if value.find('rename') is not None else None
                        is_key = column_name in key_columns
                        insert_update_info.append({
                            'step_name': step_name,
                            'table_name': table_name,
                            'column_name': column_name,
                            'is_key': is_key
                        })

        state["queries"] = queries
        state["insert_update_info"] = insert_update_info
        return state

    
    def analyze_sql_files_llm(self, state: AgentState) -> AgentState:
        """Analyze the saved SQL files and suggest improvements using an LLM."""
        analysis_results = []
        prompt_template = PromptTemplate(
            input_variables=["sql_content"],
            template="""
            You are an experienced data engineer. Analyze the SQL code below and suggest improvements.
            Consider the structure of fact and dimension tables, indexing, and query performance optimizations.

            SQL Code:
            {sql_content}

            Provide your analysis and suggestions below.
            """
        )

        chain = RunnableSequence(
            prompt_template,
            self.llm
        )

        try:

            for query in state["queries"]:
                file_path = query['file_name']
                with open(file_path, 'r') as file:
                    sql_content = file.read()

                response = chain.invoke({"sql_content": sql_content})
                analysis_results.append({
                    "file_name": file_path,
                    "analysis": response
                })

            state['analysis_results'] = analysis_results

            # Debugging Statement
            logging.debug(f"Analysis Results: {state['analysis_results']}")
        except Exception as e:
            logging.error(f"Error in analyze_sql_files_llm: {e}")
            raise        

        return state  
    
    def generate_markdown_llm(self, state: AgentState) -> AgentState:
        """Generate a Markdown document summarizing the workflow and providing analysis."""
        logging.debug(f"Generating Markdown with the following state: {state}")

        prompt_template = PromptTemplate(
            input_variables=["sequence", "queries", "analysis_results"],
            template="""
            Create a detailed Markdown document that summarizes the workflow. Include the following sections:

            1. **Execution Sequence:** List the order of steps.
            2. **Steps and SQL Files:** Provide a brief description of each step and link to the corresponding .sql file.
            3. **SQL Analysis:** Include the analysis of the SQL files and suggestions for improvement.
            4. **Recommendations:** Based on the analysis, suggest how to restructure the workflow and data warehouse.

            Data:
            Sequence: {sequence}
            Queries: {queries}
            Analysis Results: {analysis_results}
            """
        )

        try:
            chain = RunnableSequence(
                prompt_template,
                self.llm
            )

            sequence_data = "\n".join([f"{idx + 1}. {seq[0]} -> {seq[1]}" for idx, seq in enumerate(state["sequence"])])
            query_data = "\n".join([f"Step: {q['step_name']} - SQL File: {q['file_name']}" for q in state["queries"]])
            analysis_data = "\n".join([f"File: {res['file_name']} - Analysis: {res['analysis']}" for res in state['analysis_results']])

            response = chain.invoke({
                "sequence": sequence_data,
                "queries": query_data,
                "analysis_results": analysis_data
            })

            state["documentation"] = response

            logging.debug(f"Generated Documentation: {state['documentation']}")
        except Exception as e:
            logging.error(f"Error in generate_markdown_llm: {e}")
            raise            

        return state

    def extract_table_column_relations_llm(self, state: AgentState) -> AgentState:
        df = self._extract_table_column_relations_llm(self.llm, state["queries"])
        state["relations"] = df
        return state
          

    def _extract_table_column_relations_llm(self, llm: Any, queries: List[Dict[str, str]]) -> pd.DataFrame:

        def _get_response_text(response: Any) -> str:
            if isinstance(response, str):
                return response
            elif hasattr(response, 'content'):
                return response.content
            elif hasattr(response, 'text'):
                return response.text
            else:
                return ""  

        prompt_template = PromptTemplate(
            input_variables=["sql"],
            template="""
            Analyze the following SQL query and extract all the table/column relationships, ensuring that the original table names are captured, even if aliases (nicknames) are used:
            {sql}
            Return a list of table/column pairs in the format:
            original_table_name,column_name
            original_table_name,column_name
            ...
            Do not include any additional text in your response, only the list of pairs.
            """
        )

        chain = RunnableSequence(
            prompt_template,
            llm
        )

        results = []

        for query in queries:
            sql_code = query['sql']
            sql_parts = self._split_sql_code(sql_code)

            for sql_part in sql_parts:
                try:
                    response = chain.invoke({"sql": sql_part})
                    response_text = _get_response_text(response)
                    lines = response_text.strip().split('\n')

                    for line in lines:
                        if ',' in line:
                            parts = line.split(',')
                            if len(parts) == 2:
                                table, column = parts
                                results.append({'nome_tabela': table.strip(), 'nome_coluna': column.strip()})
                            else:
                                logging.warning(f"Unexpected format: {line}")
                except Exception as e:
                    logging.error(f"Error processing SQL part: {e}")

        df = pd.DataFrame(results).drop_duplicates()
        return df
    
    def export_markdown_to_file(self, state: AgentState) -> AgentState:
        """Exports the generated markdown documentation to a file with the same name as the KTR file."""
        try:
            with open(self.markdown_filename, 'w', encoding='utf-8') as f:
                f.write(state["documentation"])
            logging.info(f"Markdown documentation exported to {self.markdown_filename}")
        except Exception as e:
            logging.error(f"Error exporting markdown to file: {e}")
            raise
        return state    

    def _split_sql_code(self, sql_code: str) -> List[str]:
        sql_lines = sql_code.split('\n')
        parts = []
        current_part = []
        current_length = 0

        for line in sql_lines:
            line_length = len(line.split())
            if current_length + line_length > self.max_tokens_per_part:
                parts.append('\n'.join(current_part))
                current_part = [line]
                current_length = line_length
            else:
                current_part.append(line)
                current_length += line_length

        if current_part:
            parts.append('\n'.join(current_part))

        return parts

    def create_documentation(self, state: AgentState) -> AgentState:
        """Creates Markdown documentation summarizing the KTR pipeline."""
        doc_lines = ["# Pipeline Documentation\n"]

        doc_lines.append("## Execution Sequence\n")
        for idx, (from_step, to_step) in enumerate(state["sequence"], start=1):
            doc_lines.append(f"{idx}. {from_step} -> {to_step}\n")

        doc_lines.append("## Steps and SQL Summaries\n")
        for query in state["queries"]:
            doc_lines.append(f"### Step: {query['step_name']}\n")
            doc_lines.append(f"- Type: {query['step_type']}\n")
            doc_lines.append("#### SQL Summary:\n")
            doc_lines.append(f"```sql\n{query['sql'][:200]}...\n```\n")

        doc_lines.append("## Table/Column Relationships\n")
        for _, row in state["relations"].iterrows():
            doc_lines.append(f"- {row['nome_tabela']} -> {row['nome_coluna']}\n")

        state["documentation"] = "\n".join(doc_lines)
        return state

    def create_execution_graph(self, state: AgentState) -> AgentState:
        self.create_flow_graph(state["sequence"])
        return state

    def create_flow_graph(self, hops: List[Tuple[str, str]], output_file: str = "flow_graph.png"):
        graph = pgv.AGraph(directed=True)
        
        for from_step, to_step in hops:
            graph.add_node(from_step, shape="box")
            graph.add_node(to_step, shape="box")
            graph.add_edge(from_step, to_step)
        
        graph.layout(prog='dot')
        graph.draw(output_file)
        logging.info(f"Data flow saved in {output_file}")

    def run(self) -> AgentState:
        initial_state = AgentState(
            messages=[],
            file_path=self.file_path,
            root=None,
            sequence=[],
            queries=[],
            relations=pd.DataFrame(),
            documentation="",
            analysis_results=[],
            insert_update_info=[]
        )
        try:
            final_state = self.graph.invoke(initial_state)
            return final_state
        except Exception as e:
            logging.error(f"Error running agent pipeline: {e}")
            raise

# %%
model = OllamaLLM(model='qwen2:latest', temperature=0.0)

# %%
# model = ChatGoogleGenerativeAI(
#     model='gemini-1.5-pro-exp-0801',
#     temperature=0
# )

# %%
tool = []

# %%
prompt = ""

# %%
abot = Agent(model=model, tools=None, file_path=pentaho_file_path)

# %%
abot.run()
# Out:
# 2024-08-25 12:44:23,643 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:45:38,992 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:47:00,536 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:48:45,327 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:51:03,693 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:52:34,650 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:53:58,626 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:55:15,712 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:56:07,119 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:57:21,049 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2024-08-25 12:58:40,682 - INFO - Data flow saved in flow_graph.png
# 2024-08-25 12:58:40,685 - INFO - Markdown documentation exported to benef_transf.md
# {'messages': [],
#  'file_path': '../data/benef_transf.ktr',
#  'root': <Element 'transformation' at 0x79aa5bd95e40>,
#  'sequence': [('Switch / Case LOCAL FATURAMENTO',
#    'Switch / Case TITULAR RESPONSÁVEL'),
#   ('Switch / Case PESSOA RESPONSÁVEL', 'Dummy (do nothing) 2'),
#   ('Switch / Case PESSOA RESPONSÁVEL', 'FAMILIA PESSOA RESPONSÁVEL'),
#   ('Switch / Case TITULAR RESPONSÁVEL', 'FAMILIA TITULAR RESPONSÁVEL'),
#   ('Switch / Case TITULAR RESPONSÁVEL', 'Switch / Case PESSOA RESPONSÁVEL'),
#   ('Dummy (do nothing)', 'Remover colunas'),
#   ('Remover colunas', 'Switch / Case LOCAL FATURAMENTO'),
#   ('BENEFICIÁRIO', 'SAM_FAMILIA_TETO_PF'),
#   ('SAM_FAMILIA_TETO_PF', 'Dummy (do nothing)'),
#   ('SEM SETOR', 'Insert / Update - BN_BENEFICIARIO'),
#   ('Insert / Update - BN_BENEFICIARIO', 'QTD_INCATU_BN_BENEFICIARIO'),
#   ('Filter rows', 'BUSCA MICROSIGA'),
#   ('BUSCA MICROSIGA', 'Insert / Update - BN_BENEFICIARIO'),
#   ('HANDLE_BENEFICIARIO', 'BENEFICIÁRIO'),
#   ('Filter rows', 'SEM SETOR'),
#   ('Blocking Step', 'Set Variables'),
#   ('QTD_INCATU_BN_BENEFICIARIO', 'Blocking Step'),
#   ('Dummy (do nothing)', 'Filter rows'),
#   ('Blocking Step 2', 'Set Variables 2'),
#   ('CONTRATO', 'Insert / Update - BN_RESP_FINANCEIRO'),
#   ('FAMILIA PESSOA RESPONSÁVEL', 'Insert / Update - BN_RESP_FINANCEIRO'),
#   ('FAMILIA TITULAR RESPONSÁVEL', 'Insert / Update - BN_RESP_FINANCEIRO'),
#   ('Insert / Update - BN_RESP_FINANCEIRO', 'QTD_INCATU_BN_RESP_FINANCEIRO'),
#   ('LOTAÇÃO', 'Insert / Update - BN_RESP_FINANCEIRO'),
#   ('QTD_INCATU_BN_RESP_FINANCEIRO', 'Blocking Step 2'),
#   ('Switch / Case LOCAL FATURAMENTO', 'CONTRATO'),
#   ('Switch / Case LOCAL FATURAMENTO', 'LOTAÇÃO')],
#  'queries': [{'step_name': 'BENEFICIÁRIO',
#    'step_type': 'DBJoin',
#    'sql': "SELECT \n       BEN.HANDLE                                                                         AS ID_BENEFICIARIO\n      ,FAM.HANDLE                                                                         AS ID_FAMILIA\n      ,CON.HANDLE                                                                         AS ID_CONTRATANTE\n      ,NVL(LOT.HANDLE,0)                                                                  AS ID_CONTRATANTE_LOT\n      ,PLA.HANDLE                                                                         AS ID_PLANO\n      ,(SELECT MAX(BEN_TIT.HANDLE) \n        FROM   SAM_BENEFICIARIO BEN_TIT \n        WHERE  BEN_TIT.FAMILIA   = BEN.FAMILIA \n        AND    BEN_TIT.EHTITULAR = 'S')                                                   AS ID_BENEFICIARIO_RESP\n      ,CASE\n         WHEN CON.LOCALFATURAMENTO = 'C' THEN CPES.HANDLE --CPES\n         WHEN CON.LOCALFATURAMENTO = 'L' THEN LPES.HANDLE --LPES\n         WHEN CON.LOCALFATURAMENTO = 'F' THEN\n           CASE\n             WHEN FAM.TITULARRESPONSAVEL IS NOT NULL THEN FBEN.HANDLE --FBEN\n             WHEN FAM.PESSOARESPONSAVEL  IS NOT NULL THEN SFNP.HANDLE --SFNP\n           END\n       END                                                                                AS ID_RESP_FINANCEIRO\n      ,CASE\n        WHEN BEN.DATACANCELAMENTO < SYSDATE THEN BEN.MOTIVOCANCELAMENTO\n        WHEN MCAN.CODIGO = 101 AND (BEN.TABORIGEM = 3 OR (BEN.TABORIGEM = 2 AND CON.ESPELHO = 'S')) THEN NULL\n        ELSE BEN.MOTIVOCANCELAMENTO\n       END                                                                                 AS ID_MOTIVO_CANC\n       --Dados Beneficiario\n      ,SUBSTR(BEN.BENEFICIARIO,1,4)                                                        AS CODIGO_UNI_PAG\n      ,BEN.CODIGODEAFINIDADE                                                               AS CODIGO_AFINIDADE\n      ,BEN.BENEFICIARIO                                                                    AS CODIGO_BENEFICIARIO\n      ,BEN.CODIGODEORIGEM                                                                  AS CODIGO_ORIGEM\n      ,BEN.CODIGOANS                                                                       AS COD_BENEFICIARIO_ANS -- Código que deve ser utilizado - RN da ANS nº 250\n      ,BEN.DATAADESAO                                                                      AS DATA_ADESAO\n      ,BEN.DATAPRIMEIRAADESAO                                                              AS DATA_PRIM_ADESAO_BENEF\n      ,BEN.ATENDIMENTOATE                                                                  AS DATA_ATENDIMENTO_ATE\n      ,BEN.DATAULTIMAATUCADASTRAL                                                          AS DATA_ULTIMA_ATU_CADASTRAL\n      ,BEN.DATAADAPTACAO                                                                   AS DATA_ADAPTACAO \n      ,BEN.IDADEADAPTACAO                                                                  AS IDADE_ADAPTACAO\n      ,BEN.DIASCOMPRACARENCIA                                                              AS DIAS_COMPRA_CARENCIA\n      ,BEN.EMAIL                                                                           AS EMAIL\n      ,BEN.SEQUENCIA                                                                       AS SEQUENCIA\n      ,BEN.CCO                                                                             AS CCO\n      ,BEN.CCODV                                                                           AS CCO_DV\n      ,BEN.K_EMAIL                                                                         AS K_EMAIL_ZENITE\n      ,BEN.K_TELEFONE1                                                                     AS K_TELEFONE1_ZENITE\n      ,BEN.K_TELEFONE2                                                                     AS K_TELEFONE2_ZENITE\n      ,BEN.K_EMAILIRIS                                                                     AS K_EMAIL_IRIS\n      ,BEN.K_EMAILIW                                            ...
#    'file_name': 'sql_files/query_1.sql'},
#   {'step_name': 'BUSCA MICROSIGA',
#    'step_type': 'DBJoin',
#    'sql': 'SELECT TRIM(B.CTT_DESC01) AS SETOR_UNIMED,\n        TRIM(A.RA_TELEFON) AS TELEFONE/*,\n        TRIM(A.RA_EMAIL)   AS EMAIL*/\n  FROM SIGA.VW_SRA010 A,\n        SIGA.CTT010 B\n WHERE A.RA_MAT = ?\n   AND B.CTT_CUSTO = A.RA_CC',
#    'file_name': 'sql_files/query_2.sql'},
#   {'step_name': 'CONTRATO',
#    'step_type': 'DBJoin',
#    'sql': "SELECT --DISTINCT \n  'P' AS TIPO_RESPONSAVEL,\n  CPES.HANDLE AS ID_RESP_FINANCEIRO,\n  CPES_ENDC.BAIRRO AS BAIRRO,\n  CPES_ENDC.CEP AS CEP,\n  CPES_MUNENDC.NOME AS CIDADE,\n  CPES.CNPJCPF AS CNPJ_CPF,\n  CPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  CPES.NOME AS CONTRAT_PAGADOR_NOME,\n  CPES.DATASAIDA AS DATA_EXCLUSAO,\n  CPES.DATAENTRADA AS DATA_INCLUSAO,\n  CPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  CPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  CPES_ENDC.DDD1 AS DDD,\n  CPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT CPES_AGE.AGENCIA FROM SFN_AGENCIA CPES_AGE, SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND CPES_CFIC.AGENCIA = CPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT CPES_BAN.CODIGO FROM SFN_BANCO CPES_BAN, SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND CPES_CFIC.BANCO = CPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT CPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT CPES_CFIC.DV FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  CPES.EMAIL AS EMAIL,\n  '('||CPES_ENDC.DDD1||') '||CPES_ENDC.PREFIXO1||'-'||CPES_ENDC.NUMERO1 AS FONE,\n  '('||CPES_ENDC.DDDCELULAR||') '||CPES_ENDC.PREFIXOCELULAR||'-'||CPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||CPES_ENDC.DDD1||') '||CPES_ENDC.PREFIXO1||'-'||CPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  CPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  CPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN CPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN CPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = CPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINICIAL ...
#    'file_name': 'sql_files/query_3.sql'},
#   {'step_name': 'FAMILIA PESSOA RESPONSÁVEL',
#    'step_type': 'DBJoin',
#    'sql': "SELECT --DISTINCT\n  'P' AS TIPO_RESPONSAVEL,\n  FPES.HANDLE AS ID_RESP_FINANCEIRO,\n  FPES_ENDC.BAIRRO AS BAIRRO,\n  FPES_ENDC.CEP AS CEP,\n  FPES_MUNENDC.NOME AS CIDADE,\n  FPES.CNPJCPF AS CNPJ_CPF,\n  FPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  FPES.NOME AS CONTRAT_PAGADOR_NOME,\n  FPES.DATASAIDA AS DATA_EXCLUSAO,\n  FPES.DATAENTRADA AS DATA_INCLUSAO,\n  FPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  FPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  FPES_ENDC.DDD1 AS DDD,\n  FPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT FPES_AGE.AGENCIA FROM SFN_AGENCIA FPES_AGE, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.AGENCIA = FPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT FPES_BAN.CODIGO FROM SFN_BANCO FPES_BAN, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.BANCO = FPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT FPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT FPES_CFIC.DV FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  FPES.EMAIL AS EMAIL,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE,\n  '('||FPES_ENDC.DDDCELULAR||') '||FPES_ENDC.PREFIXOCELULAR||'-'||FPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  FPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  FPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN FPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN FPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = FPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINICIAL  ...
#    'file_name': 'sql_files/query_4.sql'},
#   {'step_name': 'FAMILIA TITULAR RESPONSÁVEL',
#    'step_type': 'DBJoin',
#    'sql': "SELECT --DISTINCT\n  'B' AS TIPO_RESPONSAVEL,\n  FBEN.HANDLE AS ID_RESP_FINANCEIRO,\n  FBEN_ENDC.BAIRRO AS BAIRRO,\n  FBEN_ENDC.CEP AS CEP,\n  FBEN_MUNENDC.NOME AS CIDADE,\n  FBEN_MAT.CPF AS CNPJ_CPF,\n  FBEN_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  FBEN.NOME AS CONTRAT_PAGADOR_NOME,\n  FBEN.DATACANCELAMENTO AS DATA_EXCLUSAO,\n  FBEN.DATAADESAO AS DATA_INCLUSAO,\n  FBEN_MAT.DATANASCIMENTO AS DATA_NASCIMENTO,\n  FBEN_ENDC.DDDCELULAR AS DDD_CELULAR,\n  FBEN_ENDC.DDD1 AS DDD,\n  FBEN_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S'\n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT FBEN_AGE.AGENCIA FROM SFN_AGENCIA FBEN_AGE, SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND FBEN_CFIC.AGENCIA = FBEN_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT FBEN_BAN.CODIGO FROM SFN_BANCO FBEN_BAN, SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND FBEN_CFIC.BANCO = FBEN_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT FBEN_CFIC.CONTACORRENTE FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT FBEN_CFIC.DV FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  NULL AS EMAIL,\n  '('||FBEN_ENDC.DDD1||') '||FBEN_ENDC.PREFIXO1||'-'||FBEN_ENDC.NUMERO1 AS FONE,\n  '('||FBEN_ENDC.DDDCELULAR||') '||FBEN_ENDC.PREFIXOCELULAR||'-'||FBEN_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  NULL AS FONE_COMERCIAL,\n  FBEN_ENDC.LOGRADOURO AS LOGRADOURO,\n  FBEN_ENDC.NUMERO AS NUMERO,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1) = 1 THEN\n      'DEBITO AUTOMATICO'\n    WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1) = 1 THEN\n      'BOLETO'\n    ELSE\n      (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  'F' AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = FBEN_ENDC.ESTADO) AS UF,\n  CBO.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINICIAL AS DATA_INICIAL_DEBITO_AUT\n,NVL(FAM.HANDLE,0) AS ID_FAMILIA\nFROM\n  SAM_BENEFICIARIO BEN\n  JOIN SAM_FAMILIA ...
#    'file_name': 'sql_files/query_5.sql'},
#   {'step_name': 'HANDLE_BENEFICIARIO',
#    'step_type': 'TableInput',
#    'sql': 'SELECT BEN.HANDLE AS HANDLE_BENEFICIARIO \nFROM   SAM_BENEFICIARIO BEN\nORDER BY 1 DESC',
#    'file_name': 'sql_files/query_6.sql'},
#   {'step_name': 'LOTAÇÃO',
#    'step_type': 'DBJoin',
#    'sql': "SELECT -- DISTINCT \n  'P' AS TIPO_RESPONSAVEL,\n  LPES.HANDLE AS ID_RESP_FINANCEIRO,\n  LPES_ENDC.BAIRRO AS BAIRRO,\n  LPES_ENDC.CEP AS CEP,\n  LPES_MUNENDC.NOME AS CIDADE,\n  LPES.CNPJCPF AS CNPJ_CPF,\n  LPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  LPES.NOME AS CONTRAT_PAGADOR_NOME,\n  LPES.DATASAIDA AS DATA_EXCLUSAO,\n  LPES.DATAENTRADA AS DATA_INCLUSAO,\n  LPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  LPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  LPES_ENDC.DDD1 AS DDD,\n  LPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT LPES_AGE.AGENCIA FROM SFN_AGENCIA LPES_AGE, SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND LPES_CFIC.AGENCIA = LPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT LPES_BAN.CODIGO FROM SFN_BANCO LPES_BAN, SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND LPES_CFIC.BANCO = LPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT LPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT LPES_CFIC.DV FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  LPES.EMAIL AS EMAIL,\n  '('||LPES_ENDC.DDD1||') '||LPES_ENDC.PREFIXO1||'-'||LPES_ENDC.NUMERO1 AS FONE,\n  '('||LPES_ENDC.DDDCELULAR||') '||LPES_ENDC.PREFIXOCELULAR||'-'||LPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||LPES_ENDC.DDD1||') '||LPES_ENDC.PREFIXO1||'-'||LPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  LPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  LPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN LPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN LPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = LPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINICIA ...
#    'file_name': 'sql_files/query_7.sql'},
#   {'step_name': 'SAM_FAMILIA_TETO_PF',
#    'step_type': 'DBJoin',
#    'sql': 'SELECT FT.DATAINICIAL AS DATA_INICIAL_TETO_COBRANCA\n      ,FT.DATAFINAL   AS DATA_FINAL_TETO_COBRANCA\n      ,FT.VALORTETOPF AS VALOR_TETO_COBRANCA\nFROM   SAM_FAMILIA_TETO_PF FT \nWHERE  FT.FAMILIA = ?\nAND    FT.HANDLE  = (SELECT MAX(FT1.HANDLE) FROM SAM_FAMILIA_TETO_PF FT1 WHERE FT1.FAMILIA = FT.FAMILIA)',
#    'file_name': 'sql_files/query_8.sql'},
#   {'step_name': 'SEM SETOR',
#    'step_type': 'DBJoin',
#    'sql': "SELECT  NULL AS SETOR_UNIMED,\n        '('||ENDR.DDD1||') '||ENDR.PREFIXO1||'-'||ENDR.NUMERO1 AS TELEFONE\nFROM    SAM_BENEFICIARIO BEN\nLEFT JOIN SAM_ENDERECO ENDR ON BEN.ENDERECORESIDENCIAL = ENDR.HANDLE\nWHERE   BEN.HANDLE = ?",
#    'file_name': 'sql_files/query_9.sql'}],
#  'relations': Empty DataFrame
#  Columns: []
#  Index: [],
#  'documentation': "The provided SQL code aims to retrieve information about beneficiaries (`BEN`) associated with specific end-user details (`ENDR`). The query joins `SAM_BENEFICIARIO` (table BEN) with `SAM_ENDERECO` (table ENDR) based on the condition that the beneficiary's main address handle matches an end-user's address handle. It then selects certain fields from both tables and applies a WHERE clause to filter records where the beneficiary's handle equals a specified value (`?`). The output includes concatenated telephone number details from `ENDR.DDD1`, `PREFIXO1`, and `NUMERO1` columns, along with an optional column `SETOR_UNIMED` that might represent a set or unit identifier.\n\n### Potential Improvements:\n\n#### 1. **Parameterization**\nThe use of `?` in the WHERE clause suggests dynamic execution based on input parameters. This is good practice for preventing SQL injection and enhancing readability. However, ensure that this parameter handling is correctly implemented in your application layer to match the expected data type (`VARCHAR(25)`).\n\n#### 2. **Indexing**\nIndexes can significantly speed up query performance by reducing the number of disk accesses required to retrieve data. Consider creating indexes on columns used for filtering (like `BEN.HANDLE`) and join conditions (`ENDR.HANDLE`). This could be particularly beneficial if these tables have a large volume of records.\n\n#### 3. **Query Optimization**\nThe current query uses a LEFT JOIN, which might not be the most efficient approach depending on the data distribution and size. If all beneficiaries are expected to have matching end-user details (i.e., `BEN.HANDLE` always matches an `ENDR.HANDLE`), using an INNER JOIN could potentially reduce unnecessary rows in the result set.\n\n#### 4. **Handling NULLs**\nThe use of `NULLIF(BEN.HANDLE, ?)` might not be necessary if you're expecting to handle cases where `BEN.HANDLE` does not match any record in `ENDR`. If this scenario is common or expected, consider adjusting your logic to explicitly manage such outcomes.\n\n#### 5. **Query Execution Plan**\nUtilize tools like EXPLAIN PLAN (in Oracle) or equivalent features in other databases to analyze the query execution plan. This can help identify bottlenecks and suggest optimizations based on how the database engine accesses data.\n\n### Improved SQL Code Example:\n```sql\nSELECT \n    COALESCE(ENDR.DDD1, '') || ' (' || ENDR.PREFIXO1 || '-' || ENDR.NUMERO1 || ')' AS TELEFONE,\n    BEN.HANDLE AS SETOR_UNIMED  -- Simplified column aliasing for clarity\nFROM \n    SAM_BENEFICIARIO BEN\nINNER JOIN \n    SAM_ENDERECO ENDR ON BEN.ENDERECORESIDENCIAL = ENDR.HANDLE\nWHERE \n    BEN.HANDLE = 'specific_handle';  -- Replace with actual handle value\n\n-- Assuming the application layer handles dynamic execution based on `?`\n```\n\n### Additional Considerations:\n- **Data Integrity**: Ensure that there are no null values in columns used for joins (`BEN.ENDERECORESIDENCIAL` and `ENDR.HANDLE`) to avoid unexpected results.\n- **Performance Metrics**: Monitor query performance over time, especially if the data volume grows or changes significantly.\n\nBy implementing these suggestions, you can enhance the efficiency of the SQL code, ensuring it performs well under varying conditions and scales appropriately with larger datasets.",
#  'analysis_results': [{'file_name': 'sql_files/query_1.sql',
#    'analysis': "The provided SQL query appears to be a complex join operation that is designed to retrieve information about beneficiaries from multiple tables. Here's an analysis of the query:\n\n### Key Components:\n1. **Joining SAM_BENEFICIARIO_MOD** (`BENMODI`): This table likely contains information about beneficiaries who are involved in some kind of modality or process.\n\n2. **Joining SAM_UNIMED** (`UNIDESI`): This table seems to contain details related to a specific type of unit (e.g., medical units, departments) associated with the beneficiaries.\n\n3. **Joining SFN_PESSOA** (`UNIDES_PESI`): This table likely contains personal information about individuals associated with `UNIDESI`.\n\n4. **Joining SAM_BENEFICIARIO_CARTAOIDENTIF** (`CARTIDENTIF`): This table appears to contain details related to the beneficiaries' identification cards or other forms of identification.\n\n### Key Conditions:\n1. The query uses a subquery in several places, which suggests that it's designed to retrieve specific records based on certain conditions (e.g., maximum `HANDLE`, specific `SITUACAO`).\n\n2. There are multiple joins (`LEFT JOIN`) indicating that the system is trying to match beneficiaries across different tables and ensure no data loss.\n\n### Potential Improvements:\n1. **Indexing**: Given the complexity of the join operations, it might be beneficial to create indexes on columns used in `JOIN` conditions (e.g., `BENEFICIARIO`, `HANDLE`) to speed up query execution times.\n\n2. **Query Optimization**: The use of subqueries within joins can impact performance. Consider if there are alternative ways to achieve the same result without nested queries, potentially using JOINs or EXISTS clauses instead.\n\n3. **Data Normalization**: Reviewing the data model might reveal opportunities for normalization (e.g., breaking down tables that contain redundant information) which could simplify join operations and improve query efficiency.\n\n4. **Query Execution Plan**: Use a tool to analyze the execution plan of this query to identify any bottlenecks or inefficient parts of the query structure.\n\n5. **Caching Results**: If certain subqueries are executed repeatedly with no changing parameters, caching their results might be beneficial for performance optimization.\n\n6. **Data Integrity Checks**: Ensure that there are checks in place to prevent data anomalies (e.g., ensuring that `BEN.HANDLE` matches across tables).\n\n### Conclusion:\nThe query is well-structured for its purpose but could benefit from further analysis and potential optimizations based on the specific database environment, including hardware capabilities and data access patterns. Performance monitoring tools can provide insights into how these changes might impact the system's overall performance.\n\n---\n\nThis analysis assumes a general understanding of SQL queries and databases; specifics about the database schema (e.g., column types, constraints) would require more detailed knowledge to provide precise recommendations."},
#   {'file_name': 'sql_files/query_2.sql',
#    'analysis': "The SQL code provided seems to be attempting to join two tables (`SIGA.VW_SRA010` and `SIGA.CTT010`) based on certain conditions, selecting specific columns from each table after trimming the values. Here's an analysis of the code:\n\n### Analysis\n\n#### 1. **Table Joins**\n   - The query uses a simple `JOIN` clause without specifying any join type (`INNER JOIN`, `LEFT JOIN`, etc.). Assuming that all rows in both tables should be considered, this might be appropriate if there are no specific conditions for joining other than the ones specified.\n\n#### 2. **Column Selection**\n   - It selects columns from both tables and trims them before displaying.\n   - The query includes a comment about selecting `EMAIL` as well but does not include it in the SELECT clause, which might be an oversight or intentional if email data is not needed for this query.\n\n#### 3. **WHERE Clause**\n   - The WHERE clause filters records based on matching `RA_MAT` from table `SIGA.VW_SRA010` and `CTT_CUSTO` from table `SIGA.CTT010`.\n   - This implies that the data in these columns should be unique across tables for this specific query to work as intended.\n\n#### 4. **Indexing**\n   - The effectiveness of the query depends heavily on indexing. Without proper indexes, the database might have to perform a full table scan or use an index scan if appropriate indexes are present.\n   - Indexes should ideally be created on columns used in `JOIN` conditions (`RA_MAT`, `CTT_CUSTO`) and potentially on columns involved in filtering (`TRIM(B.CTT_DESC01)`).\n\n### Suggestions for Improvement\n\n#### 1. **Optimize Join Type**\n   - Consider the specific requirements of your application to determine if an INNER JOIN, LEFT JOIN, or another type is more appropriate.\n\n#### 2. **Indexing Strategy**\n   - Ensure that there are indexes on `RA_MAT` in `SIGA.VW_SRA010`, `CTT_CUSTO` in `SIGA.CTT010`, and potentially on `CTT_DESC01` if it's frequently used for filtering or joining.\n\n#### 3. **Column Selection**\n   - If the `EMAIL` column is not needed, remove its selection from the query to avoid unnecessary data retrieval.\n   - Consider using a CASE statement or COALESCE function to handle NULL values in columns that might be returned but are not selected (`EMAIL`).\n\n#### 4. **Query Optimization**\n   - Use EXPLAIN PLAN (or equivalent tools) to analyze the execution plan of your SQL queries and identify any bottlenecks.\n   - Optimize queries by using appropriate data types, avoiding unnecessary computations within SELECT clauses, and ensuring that all columns in a JOIN are indexed.\n\n#### 5. **Performance Monitoring**\n   - Regularly monitor query performance metrics (like execution time, I/O operations) to understand the impact of changes made on the database's overall health and efficiency.\n\n### Conclusion\nImproving SQL queries involves understanding both the data structure and the specific requirements of your application. By optimizing indexing strategies, refining join conditions, and carefully selecting columns, you can enhance query performance significantly. Always test modifications in a controlled environment before applying them to production systems."},
#   {'file_name': 'sql_files/query_3.sql',
#    'analysis': "The provided SQL code appears to be a SELECT statement that retrieves data from multiple tables related to a financial system. The query seems well-structured, but there are several areas where improvements can be made for better performance and readability:\n\n### 1. **Use of DISTINCT**\n   - The `DISTINCT` keyword is used in the `SELECT` clause, which might not be necessary if all columns being selected are unique by design or due to constraints (like primary keys). If this is indeed unnecessary, removing it can slightly improve query performance.\n\n### 2. **Query Optimization**\n   - **Indexing**: The use of `LEFT OUTER JOIN`s suggests that there could be missing data in some tables for certain rows in the main table (`CPES`). Ensure that appropriate indexes are created on foreign keys to speed up join operations.\n   - **Subqueries**: Subqueries can often be replaced with joins or EXISTS clauses, which might improve performance. For example:\n     ```sql\n     SELECT * FROM (\n         SELECT BEN.*, FAM.*, CON.*, CPES.*, CPES_ENDC.*, CPES_MUNENDC.*, RAMATI.*, TIPDOC.*\n         FROM SAM_BENEFICIARIO BEN JOIN SAM_FAMILIA FAM ON BEN.FAMILIA = FAM.HANDLE JOIN SAM_CONTRATO CON ON FAM.CONTRATO = CON.HANDLE JOIN SFN_PESSOA CPES ON CON.PESSOA = CPES.HANDLE LEFT OUTER JOIN SAM_ENDERECO CPES_ENDC ON CPES.ENDERECOCORRESPONDENCIA = CPES_ENDC.HANDLE LEFT OUTER JOIN MUNICIPIOS CPES_MUNENDC ON CPES_ENDC.MUNICIPIO = CPES_MUNENDC.HANDLE LEFT JOIN SAM_RAMOATIVIDADE RAMATI ON CPES.RAMOATIVIDADE = RAMATI.HANDLE\n     ) T\n     WHERE BEN.HANDLE = ?\n     ```\n   - **Avoid SELECT ***: Instead of using `SELECT *`, explicitly list the columns needed. This can help in avoiding unnecessary data transfer and improve performance.\n\n### 3. **Use of JOINs**\n   - The use of `LEFT OUTER JOIN`s is appropriate if there might be missing data, but ensure that all necessary tables are joined to cover all possible scenarios.\n\n### 4. **Data Type Considerations**\n   - Ensure that the data types used in joins (`JOIN`, `ON`) match between related columns (e.g., `HANDLE`).\n\n### 5. **Use of Views**\n   - If certain complex queries or transformations are reused, consider creating a view for them to avoid repeating logic.\n\n### 6. **Parameterization**\n   - The use of `?` as a placeholder in the `WHERE` clause is good practice for preventing SQL injection and improving readability.\n\n### 7. **Performance Metrics**\n   - Use EXPLAIN PLAN or equivalent tools to analyze query execution plans before making any changes, ensuring that optimizations are effective.\n\n### Implementation:\nTo implement these suggestions, you would need to modify the SQL code accordingly, considering the specific database system's syntax and capabilities. The above points provide a general guideline for optimization based on common practices in SQL query writing.\n\n### Conclusion:\nThe provided SQL code is functional but can be optimized by removing unnecessary `DISTINCT`, improving indexing strategies, potentially replacing subqueries with joins or EXISTS clauses, explicitly listing columns instead of using `SELECT *`, and considering the use of views for repetitive queries. Always test any changes to ensure they do not introduce new issues while improving performance."},
#   {'file_name': 'sql_files/query_4.sql',
#    'analysis': 'The provided SQL code appears to be a SELECT statement that retrieves data from several tables related to financial transactions, personal information, and other details. Here are some potential improvements:\n\n### 1. **Use of CTEs (Common Table Expressions)**\n   - **Explanation**: CTEs can help improve readability and maintainability by breaking down complex queries into smaller, more manageable parts.\n   - **Suggestion**: Create a CTE for each subquery that retrieves data from multiple tables to simplify the main query.\n\n### 2. **Indexing**\n   - **Explanation**: Indexes speed up data retrieval operations on databases by providing a faster way of accessing data in tables and stored procedures.\n   - **Suggestion**: Identify frequently used columns (like `HANDLE`, `PESSOA`, `DATAINICIAL`, etc.) for indexing to improve query performance.\n\n### 3. **Use of JOINs**\n   - **Explanation**: The use of LEFT OUTER JOINs can lead to the inclusion of NULL values in certain columns, which might not be desired.\n   - **Suggestion**: Consider using INNER JOINs instead if you are only interested in records that exist in both tables being joined.\n\n### 4. **Use of Subqueries for Conditional Logic**\n   - **Explanation**: The use of multiple subqueries within the main query can make it complex and hard to understand, especially when dealing with conditional logic.\n   - **Suggestion**: Try to encapsulate these conditions into CASE statements or use a single SELECT statement that includes all necessary data.\n\n### 5. **Use of UNION/UNION ALL**\n   - **Explanation**: If multiple subqueries are returning the same type of data but from different sources, using UNION or UNION ALL can combine them into one result set.\n   - **Suggestion**: Evaluate if any of these subqueries could be combined to simplify the query.\n\n### 6. **Use of Explicit Data Types**\n   - **Explanation**: Using explicit data types instead of implicit ones can improve performance and clarity in queries involving calculations or comparisons.\n   - **Suggestion**: Ensure that all numeric values are explicitly cast to their appropriate data type (e.g., `NUMBER`, `INTEGER`).\n\n### 7. **Use of Parameters**\n   - **Explanation**: The use of a parameter (`?`) instead of hardcoding the value can make the query more flexible and reusable.\n   - **Suggestion**: Ensure that this parameter is properly handled in the execution context to avoid SQL injection or other security issues.\n\n### Implementation Example:\n```sql\nWITH CTE_FinancialDetails AS (\n    SELECT \n        CONFIN.HANDLE,\n        CONFIN.TABGERACAOREC,\n        CFC.DATAINICIAL AS DATA_INICIAL_DEBITO_AUT\n    FROM SFN_CONTAFIN CONFIN\n    LEFT JOIN SFN_CONTAFIN_COMPLEMENTO CFC ON (CFC.CONTAFINANCEIRA = CONFIN.HANDLE AND CFC.FAMILIA = FAM.HANDLE)\n),\nCTE_PersonalDetails AS (\n    SELECT \n        FPES.*, \n        FPES_ENDC.*, \n        FPES_MUNENDC.*, \n        RAMATI.*, \n        TIPDOC.*\n    FROM SFN_PESSOA FPES\n    LEFT JOIN SAM_ENDERECO FPES_ENDC ON FPES.ENDERECOCORRESPONDENCIA = FPES_ENDC.HANDLE\n    LEFT JOIN MUNICIPIOS FPES_MUNENDC ON FPES_ENDC.MUNICIPIO = FPES_MUNENDC.HANDLE\n    LEFT JOIN SAM_RAMOATIVIDADE RAMATI ON FPES.RAMOATIVIDADE = RAMATI.HANDLE\n    LEFT JOIN SFN_TIPODOCUMENTO TIPDOC ON TIPDOC.HANDLE = CONFIN.TIPODOCUMENTOREC\n),\nCTE_BeneficiaryDetails AS (\n    SELECT \n        BEN.*, \n        FAM.*, \n        CTE_FinancialDetails.*, \n        CTE_PersonalDetails.*\n    FROM SAM_BENEFICIARIO BEN\n    JOIN SAM_FAMILIA FAM ON BEN.FAMILIA = FAM.HANDLE\n    LEFT JOIN CTE_FinancialDetails ON BEN.PESSOARESPONSAVEL = CONFIN.PESSOA\n    LEFT JOIN CTE_PersonalDetails ON FPES.HANDLE = CTE_PersonalDetails.HANDLE\n)\nSELECT \n    * \nFROM CTE_BeneficiaryDetails\nWHERE BEN.HANDLE = ?\n```\n\n### Conclusion:\nBy implementing these suggestions, the SQL query can be made more efficient and easier to understand. Always test any changes in a controlled environment before applying them to product ...
#   {'file_name': 'sql_files/query_5.sql',
#    'analysis': "The provided SQL code is quite complex, involving multiple joins and subqueries. Here are some potential improvements:\n\n### 1. **Indexing**\n   - **Identify Indexes**: Analyze the tables involved to identify which columns are frequently used in `JOIN` operations or as conditions (`WHERE`, `ORDER BY`). For example, `BEN.HANDLE`, `FBEN.HANDLE`, `CONFIN.BENEFICIARIO`, etc.\n   - **Create Indexes**: Create indexes on these columns if they don't already exist. This can significantly speed up the join and search operations.\n\n### 2. **Optimize Subqueries**\n   - **Subquery Optimization**: The subqueries used to fetch data like `DEBITO_AUT_AGENCIA`, `DEBITO_AUT_BANCO`, etc., are executed for each row in the main query, which can be inefficient. Consider creating a view or a materialized view that precomputes these values if they don't change frequently.\n   - **Use Common Table Expressions (CTEs)**: Instead of using subqueries, you could use CTEs to simplify and optimize complex queries.\n\n### 3. **Avoid Unnecessary Joins**\n   - **Review Join Conditions**: Ensure that all joins are necessary. If a join is not contributing to the final result set or if it can be replaced by an index scan, consider removing it.\n   - **Use `INNER JOIN` for Filtering**: Use `INNER JOIN` instead of `LEFT JOIN` when you're sure that certain rows will always exist in the joined table.\n\n### 4. **Parameterization**\n   - **Avoid Hardcoding Parameters**: The use of a question mark (`?`) suggests that this is part of an SQL statement being executed dynamically (e.g., via PL/SQL or another procedural language). Ensure that parameter substitution is used to prevent SQL injection attacks and improve performance.\n\n### 5. **Use `WITH` Clauses**\n   - **CTEs for Reusable Data**: If certain data retrieval patterns are repeated, consider using a CTE (`WITH`) clause to encapsulate the logic and reuse it within the query.\n\n### 6. **Optimize Query Execution Plan**\n   - **Analyze with SQL Profiler**: Use tools like Oracle's SQL Tuning Advisor or SQL Server's Query Optimizer to analyze the execution plan of your query. This can help identify bottlenecks and suggest optimizations.\n   - **Use `EXPLAIN PLAN`**: In Oracle, for example, use `EXPLAIN PLAN` to understand how the database engine is executing the query.\n\n### 7. **Update Statistics**\n   - **Refresh Statistics**: Ensure that the statistics on your tables are up-to-date. This helps the optimizer make better decisions about which execution plan to use.\n\n### Implementation Suggestions:\n1. **Review and Optimize Join Conditions**.\n2. **Create Indexes on Frequently Used Columns**.\n3. **Consider using CTEs or Views for Subqueries**.\n4. **Parameterize your queries properly**.\n5. **Analyze the query with a SQL Profiler tool**.\n\nImplementing these suggestions can lead to more efficient execution of the query, reducing both processing time and resource usage."},
#   {'file_name': 'sql_files/query_6.sql',
# ...
#    'column_name': 'UNI_ORIGEM_DESC_POLITICA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'UNI_ORIGEM_TIPO_CAMARA_COMP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DNV',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_CANCELAMENTO_FAMILIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_INICIO_REPASSE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_FINAL_REPASSE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_INICIO_INAT_FAMILIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DIA_COBRANCA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'CARTAO_NACIONAL_SAUDE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'CCO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'CCO_DV',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'CODIGO_IBGE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_VENDA_FAMILIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'ANOTACAO_ADM_FAMILIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_PRIM_ADESAO_BENEF',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'POSSUI_BIOMETRIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_INICIAL_TETO_COBRANCA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_FINAL_TETO_COBRANCA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'VALOR_TETO_COBRANCA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'TIPO_CARTAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'BLOQUEAR_RECAD_BIO_AUT_WEB',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'TELEFONE1_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'TELEFONE2_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'CELULAR_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'ENDERECO_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'NUMERO_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'COMPLEMENTO_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'BAIRRO_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'CEP_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'CIDADE_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'UF_CORRESP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'TELEFONE2',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'SETOR_UNIMED',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'COBRANCA_MES_SEGUINTE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DW_INC',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DW_ALT',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'SOFREU_ADAPTACAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_ADAPTACAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'IDADE_ADAPTACAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'NAO_TEM_CARENCIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DIAS_COMPRA_CARENCIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'ORIGEM_CARENCIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'IDADE_MAXIMA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_INCLUSAO_FAMILIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'USUARIO_INCLUSAO_FAMILIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'UNIMED_EM_CASA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'BEM_ESTAR_E_SAUDE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'SITUACAO_ATUALIZACAO_DADOS',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DV_CARTAO_BENEF',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_EMAIL_ZENITE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE1_ZENITE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE2_ZENITE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_EMAIL_IRIS',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_EMAIL_IW',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE1_IW',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE2_IW',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE3_IW',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE4_IW',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_EMAIL_SAC',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE_RES_SAC',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE_CONTATO_SAC',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'K_TELEFONE_CELULAR_SAC',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_ULTIMA_ATU_CADASTRAL',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_ULTIMO_REAJUSTE_FAMILIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'ORIGEM',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_FALECIMENTO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_ATENDIMENTO_ATE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_INICIAL_VALIDADE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DATA_FINAL_VALIDADE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'SITUACAO_CARTAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'VALOR_FATURADO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'NUMERO_FATURA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'VIA_CARTAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_BENEFICIARIO',
#    'table_name': 'BN_BENEFICIARIO',
#    'column_name': 'DESCRICAO_ROTINA_CARTAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'TIPO_RESPONSAVEL',
#    'is_key': True},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'ID_RESP_FINANCEIRO',
#    'is_key': True},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'ID_FAMILIA',
#    'is_key': True},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'BAIRRO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'CEP',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'CIDADE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'CNPJ_CPF',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'COMPLEMENTO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'CONTRAT_PAGADOR_NOME',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DATA_EXCLUSAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DATA_INCLUSAO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DATA_NASCIMENTO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DDD_CELULAR',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DDD',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DDD_COMERCIAL',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DEBITO_AUT',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DEBITO_AUT_AGENCIA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DEBITO_AUT_BANCO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DEBITO_AUT_CONTA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DEBITO_AUT_DIGITO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'EMAIL',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'FONE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'FONE_CELULAR',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'FONE_COMERCIAL',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'LOGRADOURO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'NUMERO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'TIPO_COBRANCA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'TIPO_PESSOA',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'UF',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'RAMO_DE_ATIVIDADE',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'TIPO_DOCUMENTO',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DATA_INICIAL_DEBITO_AUT',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DW_INC',
#    'is_key': False},
#   {'step_name': 'Insert / Update - BN_RESP_FINANCEIRO',
#    'table_name': 'BN_RESP_FINANCEIRO',
#    'column_name': 'DW_ALT',
#    'is_key': False}]}

# %%
from IPython.display import Image
Image(abot.graph.get_graph().draw_png())
