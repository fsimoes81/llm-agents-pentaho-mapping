# %%
import xml.etree.ElementTree as ET
import logging
import re
import os
import pygraphviz as pgv
from pydantic import BaseModel
from typing import Any, Dict, List, Tuple, TypedDict, Annotated
from textwrap import dedent
from crewai_tools import tool, FileWriterTool
from crewai import Agent, Crew, Process, Task
from langchain_ollama.llms import OllamaLLM
from langchain_groq import ChatGroq
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
pentaho_file_path = '../data/benef_transf.ktr'

# %%
def parse_ktr_file(file_path) -> ET.Element:
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()
    except ET.ParseError as e:
        logging.error(f"Error parsing KTR file: {e}")
        raise
    return root

# %%
def extract_execution_sequence(root: ET.Element) -> List[Tuple[str, str]]:
    hops = []
    for hop in root.findall('.//hop'):
        from_step = hop.find('from').text
        to_step = hop.find('to').text
        enabled = hop.find('enabled').text
        if enabled == 'Y':
            hops.append((from_step, to_step))
    
    return hops

# %%
def create_flow_graph(hops: List[Tuple[str, str]], output_file: str = "flow_graph.png"):
    graph = pgv.AGraph(directed=True)
    
    for from_step, to_step in hops:
        #print(f'from: {from_step} to {to_step}')

        graph.add_node(from_step, shape="box")
        graph.add_node(to_step, shape="box")
        graph.add_edge(from_step, to_step)
    
    graph.layout(prog='dot')
    graph.draw(output_file)


    logging.info(f"Data flow saved in {output_file}")

# %%
def extract_sql_queries(steps: List[Tuple[str, str]]) -> Dict[str, Any]:
    active_steps = set(steps for seq in state["sequence"] for step in seq)
    sql_steps = state["root"].findall(".//step")
    queries = []
    
    for step in sql_steps:
        step_name = step.find("name").text
        step_type = step.find("type").text
        if step_type in ['TableInput', 'DBJoin'] and step_name in active_steps:
            sql_element = step.find("sql")
            if sql_element is not None and sql_element.text:
                queries.append({
                    "step_name": step_name,
                    "step_type": step_type,
                    "sql": sql_element.text
                })
    
    state["queries"] = queries
    return state

# %%
root = parse_ktr_file(pentaho_file_path)

# %%
hops = extract_execution_sequence(root)

# %%
active_steps = []
for i in hops:
    active_steps.append(i[0])

# %%
list(dict.fromkeys(active_steps))
# Out:
# ['Switch / Case LOCAL FATURAMENTO',
#  'Switch / Case PESSOA RESPONSÁVEL',
#  'Switch / Case TITULAR RESPONSÁVEL',
#  'Dummy (do nothing)',
#  'Remover colunas',
#  'BENEFICIÁRIO',
#  'SAM_FAMILIA_TETO_PF',
#  'SEM SETOR',
#  'Insert / Update - BN_BENEFICIARIO',
#  'Filter rows',
#  'BUSCA MICROSIGA',
#  'HANDLE_BENEFICIARIO',
#  'Blocking Step',
#  'QTD_INCATU_BN_BENEFICIARIO',
#  'Blocking Step 2',
#  'CONTRATO',
#  'FAMILIA PESSOA RESPONSÁVEL',
#  'FAMILIA TITULAR RESPONSÁVEL',
#  'Insert / Update - BN_RESP_FINANCEIRO',
#  'LOTAÇÃO',
#  'QTD_INCATU_BN_RESP_FINANCEIRO']

# %% [markdown]
# ## Testes

# %%
class KTRTransformation():
    def __init__(self):
        self.name: str = ""
        self.order: List[str] = []
        self.steps: List[Step] = []

class Step:
    def __init__(self):
        self.name: str = ""
        self.type: str = ""

class SQLStep(Step):
    def __init__(self):
        super().__init__()
        self.sql: str = ""
        self.parameters: List[Parameter] = []

class Parameter:
    def __init__(self):
        self.name: str = ""
        self.type: str = ""

class FilterStep(Step):
    def __init__(self):
        super().__init__()
        self.send_true_to: str = ""
        self.send_false_to: str = ""
        self.conditions: List[Condition] = []

class Condition:
    def __init__(self):
        self.leftvalue: str = ""
        self.operator: str = ""
        self.rightvalue: str = ""

class InsertUpdateStep(Step):
    def __init__(self):
        super().__init__()
        self.table: str = ""
        self.keys: List[KeyValue] = []
        self.values: List[KeyValue] = []

class KeyValue:
    def __init__(self):
        self.name: str = ""
        self.field: str = ""

# %%
def parse_ktr_file(file_path: str) -> KTRTransformation:
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()
    except ET.ParseError as e:
        logging.error(f"Error parsing KTR file: {e}")
        raise

    transformation = KTRTransformation()
    
    # Extract transformation name
    transformation.name = root.find("info/name").text

    # Extract order and set active steps
    active_steps = set()
    order_element = root.find("order")
    if order_element is not None:
        for hop in order_element.findall("hop"):
            from_step = hop.find("from").text
            to_step = hop.find("to").text
            transformation.order.append((from_step, to_step))
            active_steps.add(from_step)
            active_steps.add(to_step)            

    # Extract steps
    for step_element in root.findall("step"):
        step_name = step_element.find("name").text
        step_type = step_element.find("type").text

        # Only process steps that are in the active_steps set
        if step_name not in active_steps:
            continue

        if step_type == "DBJoin" or step_type == "TableInput":
            step = SQLStep()
            step.name = step_name
            step.type = step_type
            step.sql = step_element.find("sql").text
            for param in step_element.findall("parameter/field"):
                parameter = Parameter()
                parameter.name = param.find("name").text
                parameter.type = param.find("type").text
                step.parameters.append(parameter)

        elif step_type == "FilterRows":
            step = FilterStep()
            step.name = step_name
            step.type = step_type
            step.send_true_to = step_element.find("send_true_to").text
            step.send_false_to = step_element.find("send_false_to").text
            for condition in step_element.findall("conditions"):
                cond = Condition()
                cond.leftvalue = condition.find("leftvalue").text
                cond.operator = condition.find("function").text
                cond.rightvalue = condition.find("value/text").text
                step.conditions.append(cond)

        elif step_type == "InsertUpdate":
            step = InsertUpdateStep()
            step.name = step_name
            step.type = step_type
            step.table = step_element.find("lookup/table").text
            for key in step_element.findall("lookup/key"):
                kv = KeyValue()
                kv.name = key.find("name").text
                kv.field = key.find("field").text
                step.keys.append(kv)
            for value in step_element.findall("lookup/value"):
                kv = KeyValue()
                kv.name = value.find("name").text
                kv.field = value.find("rename").text
                step.values.append(kv)

        else:
            step = Step()
            step.name = step_name
            step.type = step_type

        transformation.steps.append(step)

    return transformation

# %%
def step_to_markdown(step: Step) -> str:
    md = f"## Step: {step.name}\n\n"
    md += f"Type: {step.type}\n\n"

    if isinstance(step, SQLStep):
        md += "### SQL Query\n\n"
        md += f"```sql\n{step.sql}\n```\n\n"
        if step.parameters:
            md += "Parameters:\n"
            for param in step.parameters:
                md += f"- {param.name} ({param.type})\n"

    elif isinstance(step, FilterStep):
        md += f"Send True To: {step.send_true_to}\n"
        md += f"Send False To: {step.send_false_to}\n\n"
        md += "Conditions:\n"
        for condition in step.conditions:
            md += f"- {condition.leftvalue} {condition.operator} {condition.rightvalue}\n"

    elif isinstance(step, InsertUpdateStep):
        md += f"Table: {step.table}\n\n"
        md += "Keys:\n"
        for key in step.keys:
            md += f"- {key.name}: {key.field}\n"
        md += "\nValues:\n"
        for value in step.values:
            md += f"- {value.name}: {value.field}\n"

    return md

def convert_to_filename(input_string):
    s = re.sub(r'[^a-zA-Z0-9_\-\.~]', '_', input_string)
    return s.lower()


def transformation_to_markdown(transformation: KTRTransformation) -> str:
    md = f"# Transformation: {transformation.name}\n\n"
    md += "## Execution Order\n\n"
    for step_name in transformation.order:
        md += f"- {step_name}\n"
    md += "\n## Steps\n\n"
    for step in transformation.steps:
        md += step_to_markdown(step) + "\n"
    # return md

    md_file_name = convert_to_filename(transformation.name)+'.md'

    try:
        with open(md_file_name, 'w', encoding='utf-8') as f:
            f.write(md)
        logging.info(f"Markdown documentation exported to {md_file_name}")
    except Exception as e:
        logging.error(f"Error exporting markdown to file: {e}")
        raise
    return md

# %%
T = parse_ktr_file(pentaho_file_path)

# %%
transformation_to_markdown(T)
# Out:
# "# Transformation: BN_BENEFICIARIO - insert/update\n\n## Execution Order\n\n- ('Switch / Case LOCAL FATURAMENTO', 'Switch / Case TITULAR RESPONSÁVEL')\n- ('Switch / Case PESSOA RESPONSÁVEL', 'Dummy (do nothing) 2')\n- ('Switch / Case PESSOA RESPONSÁVEL', 'FAMILIA PESSOA RESPONSÁVEL')\n- ('Switch / Case TITULAR RESPONSÁVEL', 'FAMILIA TITULAR RESPONSÁVEL')\n- ('Switch / Case TITULAR RESPONSÁVEL', 'Switch / Case PESSOA RESPONSÁVEL')\n- ('Dummy (do nothing)', 'Remover colunas')\n- ('Remover colunas', 'Switch / Case LOCAL FATURAMENTO')\n- ('BENEFICIÁRIO', 'SAM_FAMILIA_TETO_PF')\n- ('SAM_FAMILIA_TETO_PF', 'Dummy (do nothing)')\n- ('SEM SETOR', 'Insert / Update - BN_BENEFICIARIO')\n- ('Insert / Update - BN_BENEFICIARIO', 'QTD_INCATU_BN_BENEFICIARIO')\n- ('Filter rows', 'BUSCA MICROSIGA')\n- ('BUSCA MICROSIGA', 'Insert / Update - BN_BENEFICIARIO')\n- ('HANDLE_BENEFICIARIO', 'BENEFICIÁRIO')\n- ('Filter rows', 'SEM SETOR')\n- ('Blocking Step', 'Set Variables')\n- ('QTD_INCATU_BN_BENEFICIARIO', 'Blocking Step')\n- ('Dummy (do nothing)', 'Filter rows')\n- ('Blocking Step 2', 'Set Variables 2')\n- ('CONTRATO', 'Insert / Update - BN_RESP_FINANCEIRO')\n- ('FAMILIA PESSOA RESPONSÁVEL', 'Insert / Update - BN_RESP_FINANCEIRO')\n- ('FAMILIA TITULAR RESPONSÁVEL', 'Insert / Update - BN_RESP_FINANCEIRO')\n- ('Insert / Update - BN_RESP_FINANCEIRO', 'QTD_INCATU_BN_RESP_FINANCEIRO')\n- ('LOTAÇÃO', 'Insert / Update - BN_RESP_FINANCEIRO')\n- ('QTD_INCATU_BN_RESP_FINANCEIRO', 'Blocking Step 2')\n- ('Switch / Case LOCAL FATURAMENTO', 'CONTRATO')\n- ('Switch / Case LOCAL FATURAMENTO', 'LOTAÇÃO')\n\n## Steps\n\n## Step: BENEFICIÁRIO\n\nType: DBJoin\n\n### SQL Query\n\n```sql\nSELECT \n       BEN.HANDLE                                                                         AS ID_BENEFICIARIO\n      ,FAM.HANDLE                                                                         AS ID_FAMILIA\n      ,CON.HANDLE                                                                         AS ID_CONTRATANTE\n      ,NVL(LOT.HANDLE,0)                                                                  AS ID_CONTRATANTE_LOT\n      ,PLA.HANDLE                                                                         AS ID_PLANO\n      ,(SELECT MAX(BEN_TIT.HANDLE) \n        FROM   SAM_BENEFICIARIO BEN_TIT \n        WHERE  BEN_TIT.FAMILIA   = BEN.FAMILIA \n        AND    BEN_TIT.EHTITULAR = 'S')                                                   AS ID_BENEFICIARIO_RESP\n      ,CASE\n         WHEN CON.LOCALFATURAMENTO = 'C' THEN CPES.HANDLE --CPES\n         WHEN CON.LOCALFATURAMENTO = 'L' THEN LPES.HANDLE --LPES\n         WHEN CON.LOCALFATURAMENTO = 'F' THEN\n           CASE\n             WHEN FAM.TITULARRESPONSAVEL IS NOT NULL THEN FBEN.HANDLE --FBEN\n             WHEN FAM.PESSOARESPONSAVEL  IS NOT NULL THEN SFNP.HANDLE --SFNP\n           END\n       END                                                                                AS ID_RESP_FINANCEIRO\n      ,CASE\n        WHEN BEN.DATACANCELAMENTO < SYSDATE THEN BEN.MOTIVOCANCELAMENTO\n        WHEN MCAN.CODIGO = 101 AND (BEN.TABORIGEM = 3 OR (BEN.TABORIGEM = 2 AND CON.ESPELHO = 'S')) THEN NULL\n        ELSE BEN.MOTIVOCANCELAMENTO\n       END                                                                                 AS ID_MOTIVO_CANC\n       --Dados Beneficiario\n      ,SUBSTR(BEN.BENEFICIARIO,1,4)                                                        AS CODIGO_UNI_PAG\n      ,BEN.CODIGODEAFINIDADE                                                               AS CODIGO_AFINIDADE\n      ,BEN.BENEFICIARIO                                                                    AS CODIGO_BENEFICIARIO\n      ,BEN.CODIGODEORIGEM                                                                  AS CODIGO_ORIGEM\n      ,BEN.CODIGOANS                                                                       AS COD_BENEFICIARIO_ANS -- Código que deve ser utilizado - RN da ANS nº 250\n      ,BEN.DATAADESAO                                 ...

# %% [markdown]
# # CrewAI

# %%
# model = ChatGroq(
#     model="llama3-8b-8192",
#     temperature = 0,
# )

# %%
model = ChatGoogleGenerativeAI(
    model='gemini-1.5-pro-exp-0801',
    temperature=0
)

# %%
type(T)
# Out:
# __main__.KTRTransformation

# %%
import json
import csv

# %%
class ResultCollector:
    def __init__(self, output_directory='output'):
        # self.results = []
        self.result = ""
        self.output_directory = output_directory
        os.makedirs(self.output_directory, exist_ok=True)

    def add_result(self, task_name, result, step_name):
        print(f"Adding result for task: {task_name}, step: {step_name}")
        #self.results.append({"result": result})
        self.result = result
        self.export_to_csv(f"{self.output_directory}/{step_name}.csv")

    def export_to_json(self, filename):
        with open(filename, 'w') as f:
            json.dump(self.results, f, indent=2)

    def export_to_csv(self, filename):
        if not self.result:
            print("No results to export.")
            return

        #keys = self.results[-1].keys()  # Use the last result to get the keys
        print(f"Exporting result to {filename}")
        with open(filename, 'w', newline='') as f:
            #writer = csv.DictWriter(f, fieldnames=keys)
            writer = csv.writer(f)
            #writer.writeheader()
            #writer.writerow(self.results[-1])  # Write only the last result
            writer.writerow(self.result)

# %%
result_collector = ResultCollector()

# %%
T.steps
# Out:
# [<__main__.SQLStep at 0x7f1d982c4e20>,
#  <__main__.SQLStep at 0x7f1d80078130>,
#  <__main__.Step at 0x7f1d80079d20>,
#  <__main__.Step at 0x7f1d8007b490>,
#  <__main__.SQLStep at 0x7f1d8007a3e0>,
#  <__main__.Step at 0x7f1d8007a2f0>,
#  <__main__.Step at 0x7f1d8007b1c0>,
#  <__main__.SQLStep at 0x7f1d8007b1f0>,
#  <__main__.SQLStep at 0x7f1d80078070>,
#  <__main__.FilterStep at 0x7f1d800792a0>,
#  <__main__.SQLStep at 0x7f1d8007a440>,
#  <__main__.InsertUpdateStep at 0x7f1d800780a0>,
#  <__main__.InsertUpdateStep at 0x7f1d8007b6d0>,
#  <__main__.SQLStep at 0x7f1d800c4c10>,
#  <__main__.Step at 0x7f1d800e0340>,
#  <__main__.Step at 0x7f1d800e07f0>,
#  <__main__.Step at 0x7f1d800e05e0>,
#  <__main__.SQLStep at 0x7f1d800e09d0>,
#  <__main__.SQLStep at 0x7f1d800e06a0>,
#  <__main__.Step at 0x7f1d800e1f00>,
#  <__main__.Step at 0x7f1d800e19f0>,
#  <__main__.Step at 0x7f1d800e1a50>,
#  <__main__.Step at 0x7f1d800e0b50>,
#  <__main__.Step at 0x7f1d800e0790>]

# %%
def query_list(steps: list):
    """ 
    Input a tranformed ktr structure, output a list of queries.
    """
    queries = []  

    for step in T.steps:
        if step.type in ['DBJoin', 'TableInput']:
            queries.append({
                'step_name': step.name,
                'sql_code': step.sql 
            })  
    return queries

# %%
list_of_queries = query_list(T.steps)

# %%
list_of_queries
# Out:
# [{'step_name': 'BENEFICIÁRIO',
#   'sql_code': "SELECT \n       BEN.HANDLE                                                                         AS ID_BENEFICIARIO\n      ,FAM.HANDLE                                                                         AS ID_FAMILIA\n      ,CON.HANDLE                                                                         AS ID_CONTRATANTE\n      ,NVL(LOT.HANDLE,0)                                                                  AS ID_CONTRATANTE_LOT\n      ,PLA.HANDLE                                                                         AS ID_PLANO\n      ,(SELECT MAX(BEN_TIT.HANDLE) \n        FROM   SAM_BENEFICIARIO BEN_TIT \n        WHERE  BEN_TIT.FAMILIA   = BEN.FAMILIA \n        AND    BEN_TIT.EHTITULAR = 'S')                                                   AS ID_BENEFICIARIO_RESP\n      ,CASE\n         WHEN CON.LOCALFATURAMENTO = 'C' THEN CPES.HANDLE --CPES\n         WHEN CON.LOCALFATURAMENTO = 'L' THEN LPES.HANDLE --LPES\n         WHEN CON.LOCALFATURAMENTO = 'F' THEN\n           CASE\n             WHEN FAM.TITULARRESPONSAVEL IS NOT NULL THEN FBEN.HANDLE --FBEN\n             WHEN FAM.PESSOARESPONSAVEL  IS NOT NULL THEN SFNP.HANDLE --SFNP\n           END\n       END                                                                                AS ID_RESP_FINANCEIRO\n      ,CASE\n        WHEN BEN.DATACANCELAMENTO < SYSDATE THEN BEN.MOTIVOCANCELAMENTO\n        WHEN MCAN.CODIGO = 101 AND (BEN.TABORIGEM = 3 OR (BEN.TABORIGEM = 2 AND CON.ESPELHO = 'S')) THEN NULL\n        ELSE BEN.MOTIVOCANCELAMENTO\n       END                                                                                 AS ID_MOTIVO_CANC\n       --Dados Beneficiario\n      ,SUBSTR(BEN.BENEFICIARIO,1,4)                                                        AS CODIGO_UNI_PAG\n      ,BEN.CODIGODEAFINIDADE                                                               AS CODIGO_AFINIDADE\n      ,BEN.BENEFICIARIO                                                                    AS CODIGO_BENEFICIARIO\n      ,BEN.CODIGODEORIGEM                                                                  AS CODIGO_ORIGEM\n      ,BEN.CODIGOANS                                                                       AS COD_BENEFICIARIO_ANS -- Código que deve ser utilizado - RN da ANS nº 250\n      ,BEN.DATAADESAO                                                                      AS DATA_ADESAO\n      ,BEN.DATAPRIMEIRAADESAO                                                              AS DATA_PRIM_ADESAO_BENEF\n      ,BEN.ATENDIMENTOATE                                                                  AS DATA_ATENDIMENTO_ATE\n      ,BEN.DATAULTIMAATUCADASTRAL                                                          AS DATA_ULTIMA_ATU_CADASTRAL\n      ,BEN.DATAADAPTACAO                                                                   AS DATA_ADAPTACAO \n      ,BEN.IDADEADAPTACAO                                                                  AS IDADE_ADAPTACAO\n      ,BEN.DIASCOMPRACARENCIA                                                              AS DIAS_COMPRA_CARENCIA\n      ,BEN.EMAIL                                                                           AS EMAIL\n      ,BEN.SEQUENCIA                                                                       AS SEQUENCIA\n      ,BEN.CCO                                                                             AS CCO\n      ,BEN.CCODV                                                                           AS CCO_DV\n      ,BEN.K_EMAIL                                                                         AS K_EMAIL_ZENITE\n      ,BEN.K_TELEFONE1                                                                     AS K_TELEFONE1_ZENITE\n      ,BEN.K_TELEFONE2                                                                     AS K_TELEFONE2_ZENITE\n      ,BEN.K_EMAILIRIS                                                                     AS K_EMAIL_IRIS\n      ,BEN.K_EMAILIW                                        ...
#  {'step_name': 'BUSCA MICROSIGA',
#   'sql_code': 'SELECT TRIM(B.CTT_DESC01) AS SETOR_UNIMED,\n        TRIM(A.RA_TELEFON) AS TELEFONE/*,\n        TRIM(A.RA_EMAIL)   AS EMAIL*/\n  FROM SIGA.VW_SRA010 A,\n        SIGA.CTT010 B\n WHERE A.RA_MAT = ?\n   AND B.CTT_CUSTO = A.RA_CC'},
#  {'step_name': 'CONTRATO',
#   'sql_code': "SELECT --DISTINCT \n  'P' AS TIPO_RESPONSAVEL,\n  CPES.HANDLE AS ID_RESP_FINANCEIRO,\n  CPES_ENDC.BAIRRO AS BAIRRO,\n  CPES_ENDC.CEP AS CEP,\n  CPES_MUNENDC.NOME AS CIDADE,\n  CPES.CNPJCPF AS CNPJ_CPF,\n  CPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  CPES.NOME AS CONTRAT_PAGADOR_NOME,\n  CPES.DATASAIDA AS DATA_EXCLUSAO,\n  CPES.DATAENTRADA AS DATA_INCLUSAO,\n  CPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  CPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  CPES_ENDC.DDD1 AS DDD,\n  CPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT CPES_AGE.AGENCIA FROM SFN_AGENCIA CPES_AGE, SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND CPES_CFIC.AGENCIA = CPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT CPES_BAN.CODIGO FROM SFN_BANCO CPES_BAN, SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND CPES_CFIC.BANCO = CPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT CPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT CPES_CFIC.DV FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  CPES.EMAIL AS EMAIL,\n  '('||CPES_ENDC.DDD1||') '||CPES_ENDC.PREFIXO1||'-'||CPES_ENDC.NUMERO1 AS FONE,\n  '('||CPES_ENDC.DDDCELULAR||') '||CPES_ENDC.PREFIXOCELULAR||'-'||CPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||CPES_ENDC.DDD1||') '||CPES_ENDC.PREFIXO1||'-'||CPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  CPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  CPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN CPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN CPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = CPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINI ...
#  {'step_name': 'FAMILIA PESSOA RESPONSÁVEL',
#   'sql_code': "SELECT --DISTINCT\n  'P' AS TIPO_RESPONSAVEL,\n  FPES.HANDLE AS ID_RESP_FINANCEIRO,\n  FPES_ENDC.BAIRRO AS BAIRRO,\n  FPES_ENDC.CEP AS CEP,\n  FPES_MUNENDC.NOME AS CIDADE,\n  FPES.CNPJCPF AS CNPJ_CPF,\n  FPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  FPES.NOME AS CONTRAT_PAGADOR_NOME,\n  FPES.DATASAIDA AS DATA_EXCLUSAO,\n  FPES.DATAENTRADA AS DATA_INCLUSAO,\n  FPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  FPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  FPES_ENDC.DDD1 AS DDD,\n  FPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT FPES_AGE.AGENCIA FROM SFN_AGENCIA FPES_AGE, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.AGENCIA = FPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT FPES_BAN.CODIGO FROM SFN_BANCO FPES_BAN, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.BANCO = FPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT FPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT FPES_CFIC.DV FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  FPES.EMAIL AS EMAIL,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE,\n  '('||FPES_ENDC.DDDCELULAR||') '||FPES_ENDC.PREFIXOCELULAR||'-'||FPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  FPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  FPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN FPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN FPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = FPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINIC ...
#  {'step_name': 'FAMILIA TITULAR RESPONSÁVEL',
#   'sql_code': "SELECT --DISTINCT\n  'B' AS TIPO_RESPONSAVEL,\n  FBEN.HANDLE AS ID_RESP_FINANCEIRO,\n  FBEN_ENDC.BAIRRO AS BAIRRO,\n  FBEN_ENDC.CEP AS CEP,\n  FBEN_MUNENDC.NOME AS CIDADE,\n  FBEN_MAT.CPF AS CNPJ_CPF,\n  FBEN_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  FBEN.NOME AS CONTRAT_PAGADOR_NOME,\n  FBEN.DATACANCELAMENTO AS DATA_EXCLUSAO,\n  FBEN.DATAADESAO AS DATA_INCLUSAO,\n  FBEN_MAT.DATANASCIMENTO AS DATA_NASCIMENTO,\n  FBEN_ENDC.DDDCELULAR AS DDD_CELULAR,\n  FBEN_ENDC.DDD1 AS DDD,\n  FBEN_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S'\n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT FBEN_AGE.AGENCIA FROM SFN_AGENCIA FBEN_AGE, SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND FBEN_CFIC.AGENCIA = FBEN_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT FBEN_BAN.CODIGO FROM SFN_BANCO FBEN_BAN, SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND FBEN_CFIC.BANCO = FBEN_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT FBEN_CFIC.CONTACORRENTE FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT FBEN_CFIC.DV FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  NULL AS EMAIL,\n  '('||FBEN_ENDC.DDD1||') '||FBEN_ENDC.PREFIXO1||'-'||FBEN_ENDC.NUMERO1 AS FONE,\n  '('||FBEN_ENDC.DDDCELULAR||') '||FBEN_ENDC.PREFIXOCELULAR||'-'||FBEN_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  NULL AS FONE_COMERCIAL,\n  FBEN_ENDC.LOGRADOURO AS LOGRADOURO,\n  FBEN_ENDC.NUMERO AS NUMERO,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1) = 1 THEN\n      'DEBITO AUTOMATICO'\n    WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1) = 1 THEN\n      'BOLETO'\n    ELSE\n      (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  'F' AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = FBEN_ENDC.ESTADO) AS UF,\n  CBO.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINICIAL AS DATA_INICIAL_DEBITO_AUT\n,NVL(FAM.HANDLE,0) AS ID_FAMILIA\nFROM\n  SAM_BENEFICIARIO BEN\n  JOIN SAM_FAM ...
#  {'step_name': 'HANDLE_BENEFICIARIO',
#   'sql_code': 'SELECT BEN.HANDLE AS HANDLE_BENEFICIARIO \nFROM   SAM_BENEFICIARIO BEN\nORDER BY 1 DESC'},
#  {'step_name': 'LOTAÇÃO',
#   'sql_code': "SELECT -- DISTINCT \n  'P' AS TIPO_RESPONSAVEL,\n  LPES.HANDLE AS ID_RESP_FINANCEIRO,\n  LPES_ENDC.BAIRRO AS BAIRRO,\n  LPES_ENDC.CEP AS CEP,\n  LPES_MUNENDC.NOME AS CIDADE,\n  LPES.CNPJCPF AS CNPJ_CPF,\n  LPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  LPES.NOME AS CONTRAT_PAGADOR_NOME,\n  LPES.DATASAIDA AS DATA_EXCLUSAO,\n  LPES.DATAENTRADA AS DATA_INCLUSAO,\n  LPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  LPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  LPES_ENDC.DDD1 AS DDD,\n  LPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT LPES_AGE.AGENCIA FROM SFN_AGENCIA LPES_AGE, SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND LPES_CFIC.AGENCIA = LPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT LPES_BAN.CODIGO FROM SFN_BANCO LPES_BAN, SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND LPES_CFIC.BANCO = LPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT LPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT LPES_CFIC.DV FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  LPES.EMAIL AS EMAIL,\n  '('||LPES_ENDC.DDD1||') '||LPES_ENDC.PREFIXO1||'-'||LPES_ENDC.NUMERO1 AS FONE,\n  '('||LPES_ENDC.DDDCELULAR||') '||LPES_ENDC.PREFIXOCELULAR||'-'||LPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||LPES_ENDC.DDD1||') '||LPES_ENDC.PREFIXO1||'-'||LPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  LPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  LPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN LPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN LPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = LPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAIN ...
#  {'step_name': 'SAM_FAMILIA_TETO_PF',
#   'sql_code': 'SELECT FT.DATAINICIAL AS DATA_INICIAL_TETO_COBRANCA\n      ,FT.DATAFINAL   AS DATA_FINAL_TETO_COBRANCA\n      ,FT.VALORTETOPF AS VALOR_TETO_COBRANCA\nFROM   SAM_FAMILIA_TETO_PF FT \nWHERE  FT.FAMILIA = ?\nAND    FT.HANDLE  = (SELECT MAX(FT1.HANDLE) FROM SAM_FAMILIA_TETO_PF FT1 WHERE FT1.FAMILIA = FT.FAMILIA)'},
#  {'step_name': 'SEM SETOR',
#   'sql_code': "SELECT  NULL AS SETOR_UNIMED,\n        '('||ENDR.DDD1||') '||ENDR.PREFIXO1||'-'||ENDR.NUMERO1 AS TELEFONE\nFROM    SAM_BENEFICIARIO BEN\nLEFT JOIN SAM_ENDERECO ENDR ON BEN.ENDERECORESIDENCIAL = ENDR.HANDLE\nWHERE   BEN.HANDLE = ?"}]

# %%
file_write_tool = FileWriterTool()

# %%
sql_analyst = Agent(
    role = "Senior Data Analyst",
    goal = "Analyse and complex sql queries and extract table name vs column name relation from all tables on the querie",
    backstory=dedent(
        """
        You're a highly specialized developed to dissect and understand complex SQL queries,
        you could quickly and accurately extract essential information from intricate SQL statements.
        Your key traits are Analytical prowess, Attention to detail, Vast knowledge of SQL syntax 
        across multiple database systems.
        """
    ),
    llm=model,
    allow_delegation=False
)

# %%
report_writer = Agent(
    role = "Senior Business Analyst",
    goal = "Write a document based on the work of analyst",
    backstory = dedent(
        """
        You writing still is well known for clear and effective communication.
        You summarize Pentahor workflow artifacts and sql queries business rules into bullet point contain de most import details.
        """
    ),
    llm=model,
    allow_delegation=False
)

# %%
extract_tables_columns = Task(
    description=dedent(
        """
        Analyse this SQL querie {sql_code}.
        Is very important use table name, not its nick name. Then extract tables e columns names.
        Get only table name and column name following this patterns:
        columns_name;table_name
        table1;columnName_n1
        table1;columnName_n2
        table2;columnName_n1
        table2;columnName_n2
        tableN;columnName_n1
        tableN;columnName_n1
        """
    ),
    expected_output="CSV file",
    agent=sql_analyst,
    #callback=lambda result: result_collector.add_result(result)
)

# %%
export_tables_columns = Task(
    description = "Get only table name and column.",
    expected_output = "CSV file",
    agent = sql_analyst,
    tools=[file_write_tool],
    context = [extract_tables_columns],
    #output_file='output/{step_name}.csv',
    #create_directory = True,
    #callback=lambda result: result_collector.add_result("export_tables_columns", result)
)

# %%
analyze_data = Task(
    description = "Analyze the query {sql_code} and write an analysis.",
    expected_output = "Detailed analysis from text for non technical public.",
    agent = sql_analyst,

)

# %%
write_report = Task(
    description=dedent(
        """
        Write an tecnical report from previous analysis, this document will be used 
        to migrate the actual project to cloud enviroment. 
        """
    ),
    expected_output = "Markdown report",
    agent=report_writer,
    context=[analyze_data]
)

# %%
# crew = Crew(
#     agents = [sql_analyst, report_writer],
#     tasks = [extract_tables_columns,format_queries,analyze_data,write_report],
#     process = Process.sequential,
#     verbose=1,
#     memory=False,
#     output_log_file="crew.log",
# )

# %%
crew = Crew(
    agents = [sql_analyst],
    tasks = [extract_tables_columns],
    process = Process.sequential,
    verbose = 0,
    memory=False,
    output_log_file="crew.log",
)
# Out:
# 2024-08-28 13:49:37,313 - 139766624456704 - __init__.py-__init__:531 - WARNING: Overriding of current TracerProvider is not allowed

# %%
list_of_queries
# Out:
# [{'step_name': 'BENEFICIÁRIO',
#   'sql_code': "SELECT \n       BEN.HANDLE                                                                         AS ID_BENEFICIARIO\n      ,FAM.HANDLE                                                                         AS ID_FAMILIA\n      ,CON.HANDLE                                                                         AS ID_CONTRATANTE\n      ,NVL(LOT.HANDLE,0)                                                                  AS ID_CONTRATANTE_LOT\n      ,PLA.HANDLE                                                                         AS ID_PLANO\n      ,(SELECT MAX(BEN_TIT.HANDLE) \n        FROM   SAM_BENEFICIARIO BEN_TIT \n        WHERE  BEN_TIT.FAMILIA   = BEN.FAMILIA \n        AND    BEN_TIT.EHTITULAR = 'S')                                                   AS ID_BENEFICIARIO_RESP\n      ,CASE\n         WHEN CON.LOCALFATURAMENTO = 'C' THEN CPES.HANDLE --CPES\n         WHEN CON.LOCALFATURAMENTO = 'L' THEN LPES.HANDLE --LPES\n         WHEN CON.LOCALFATURAMENTO = 'F' THEN\n           CASE\n             WHEN FAM.TITULARRESPONSAVEL IS NOT NULL THEN FBEN.HANDLE --FBEN\n             WHEN FAM.PESSOARESPONSAVEL  IS NOT NULL THEN SFNP.HANDLE --SFNP\n           END\n       END                                                                                AS ID_RESP_FINANCEIRO\n      ,CASE\n        WHEN BEN.DATACANCELAMENTO < SYSDATE THEN BEN.MOTIVOCANCELAMENTO\n        WHEN MCAN.CODIGO = 101 AND (BEN.TABORIGEM = 3 OR (BEN.TABORIGEM = 2 AND CON.ESPELHO = 'S')) THEN NULL\n        ELSE BEN.MOTIVOCANCELAMENTO\n       END                                                                                 AS ID_MOTIVO_CANC\n       --Dados Beneficiario\n      ,SUBSTR(BEN.BENEFICIARIO,1,4)                                                        AS CODIGO_UNI_PAG\n      ,BEN.CODIGODEAFINIDADE                                                               AS CODIGO_AFINIDADE\n      ,BEN.BENEFICIARIO                                                                    AS CODIGO_BENEFICIARIO\n      ,BEN.CODIGODEORIGEM                                                                  AS CODIGO_ORIGEM\n      ,BEN.CODIGOANS                                                                       AS COD_BENEFICIARIO_ANS -- Código que deve ser utilizado - RN da ANS nº 250\n      ,BEN.DATAADESAO                                                                      AS DATA_ADESAO\n      ,BEN.DATAPRIMEIRAADESAO                                                              AS DATA_PRIM_ADESAO_BENEF\n      ,BEN.ATENDIMENTOATE                                                                  AS DATA_ATENDIMENTO_ATE\n      ,BEN.DATAULTIMAATUCADASTRAL                                                          AS DATA_ULTIMA_ATU_CADASTRAL\n      ,BEN.DATAADAPTACAO                                                                   AS DATA_ADAPTACAO \n      ,BEN.IDADEADAPTACAO                                                                  AS IDADE_ADAPTACAO\n      ,BEN.DIASCOMPRACARENCIA                                                              AS DIAS_COMPRA_CARENCIA\n      ,BEN.EMAIL                                                                           AS EMAIL\n      ,BEN.SEQUENCIA                                                                       AS SEQUENCIA\n      ,BEN.CCO                                                                             AS CCO\n      ,BEN.CCODV                                                                           AS CCO_DV\n      ,BEN.K_EMAIL                                                                         AS K_EMAIL_ZENITE\n      ,BEN.K_TELEFONE1                                                                     AS K_TELEFONE1_ZENITE\n      ,BEN.K_TELEFONE2                                                                     AS K_TELEFONE2_ZENITE\n      ,BEN.K_EMAILIRIS                                                                     AS K_EMAIL_IRIS\n      ,BEN.K_EMAILIW                                        ...
#  {'step_name': 'BUSCA MICROSIGA',
#   'sql_code': 'SELECT TRIM(B.CTT_DESC01) AS SETOR_UNIMED,\n        TRIM(A.RA_TELEFON) AS TELEFONE/*,\n        TRIM(A.RA_EMAIL)   AS EMAIL*/\n  FROM SIGA.VW_SRA010 A,\n        SIGA.CTT010 B\n WHERE A.RA_MAT = ?\n   AND B.CTT_CUSTO = A.RA_CC'},
#  {'step_name': 'CONTRATO',
#   'sql_code': "SELECT --DISTINCT \n  'P' AS TIPO_RESPONSAVEL,\n  CPES.HANDLE AS ID_RESP_FINANCEIRO,\n  CPES_ENDC.BAIRRO AS BAIRRO,\n  CPES_ENDC.CEP AS CEP,\n  CPES_MUNENDC.NOME AS CIDADE,\n  CPES.CNPJCPF AS CNPJ_CPF,\n  CPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  CPES.NOME AS CONTRAT_PAGADOR_NOME,\n  CPES.DATASAIDA AS DATA_EXCLUSAO,\n  CPES.DATAENTRADA AS DATA_INCLUSAO,\n  CPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  CPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  CPES_ENDC.DDD1 AS DDD,\n  CPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT CPES_AGE.AGENCIA FROM SFN_AGENCIA CPES_AGE, SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND CPES_CFIC.AGENCIA = CPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT CPES_BAN.CODIGO FROM SFN_BANCO CPES_BAN, SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND CPES_CFIC.BANCO = CPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT CPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT CPES_CFIC.DV FROM SFN_CONTAFIN CPES_CFIN, SFN_CONTAFIN_COMPLEMENTO CPES_CFIC WHERE CPES_CFIN.PESSOA = CPES.HANDLE AND CPES_CFIN.HANDLE = CPES_CFIC.CONTAFINANCEIRA AND CPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( CPES_CFIC.DATAFINAL IS NULL OR CPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(CPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  CPES.EMAIL AS EMAIL,\n  '('||CPES_ENDC.DDD1||') '||CPES_ENDC.PREFIXO1||'-'||CPES_ENDC.NUMERO1 AS FONE,\n  '('||CPES_ENDC.DDDCELULAR||') '||CPES_ENDC.PREFIXOCELULAR||'-'||CPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||CPES_ENDC.DDD1||') '||CPES_ENDC.PREFIXO1||'-'||CPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  CPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  CPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = CPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN CPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN CPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = CPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINI ...
#  {'step_name': 'FAMILIA PESSOA RESPONSÁVEL',
#   'sql_code': "SELECT --DISTINCT\n  'P' AS TIPO_RESPONSAVEL,\n  FPES.HANDLE AS ID_RESP_FINANCEIRO,\n  FPES_ENDC.BAIRRO AS BAIRRO,\n  FPES_ENDC.CEP AS CEP,\n  FPES_MUNENDC.NOME AS CIDADE,\n  FPES.CNPJCPF AS CNPJ_CPF,\n  FPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  FPES.NOME AS CONTRAT_PAGADOR_NOME,\n  FPES.DATASAIDA AS DATA_EXCLUSAO,\n  FPES.DATAENTRADA AS DATA_INCLUSAO,\n  FPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  FPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  FPES_ENDC.DDD1 AS DDD,\n  FPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT FPES_AGE.AGENCIA FROM SFN_AGENCIA FPES_AGE, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.AGENCIA = FPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT FPES_BAN.CODIGO FROM SFN_BANCO FPES_BAN, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.BANCO = FPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT FPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT FPES_CFIC.DV FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  FPES.EMAIL AS EMAIL,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE,\n  '('||FPES_ENDC.DDDCELULAR||') '||FPES_ENDC.PREFIXOCELULAR||'-'||FPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  FPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  FPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN FPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN FPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = FPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINIC ...
#  {'step_name': 'FAMILIA TITULAR RESPONSÁVEL',
#   'sql_code': "SELECT --DISTINCT\n  'B' AS TIPO_RESPONSAVEL,\n  FBEN.HANDLE AS ID_RESP_FINANCEIRO,\n  FBEN_ENDC.BAIRRO AS BAIRRO,\n  FBEN_ENDC.CEP AS CEP,\n  FBEN_MUNENDC.NOME AS CIDADE,\n  FBEN_MAT.CPF AS CNPJ_CPF,\n  FBEN_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  FBEN.NOME AS CONTRAT_PAGADOR_NOME,\n  FBEN.DATACANCELAMENTO AS DATA_EXCLUSAO,\n  FBEN.DATAADESAO AS DATA_INCLUSAO,\n  FBEN_MAT.DATANASCIMENTO AS DATA_NASCIMENTO,\n  FBEN_ENDC.DDDCELULAR AS DDD_CELULAR,\n  FBEN_ENDC.DDD1 AS DDD,\n  FBEN_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S'\n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT FBEN_AGE.AGENCIA FROM SFN_AGENCIA FBEN_AGE, SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND FBEN_CFIC.AGENCIA = FBEN_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT FBEN_BAN.CODIGO FROM SFN_BANCO FBEN_BAN, SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND FBEN_CFIC.BANCO = FBEN_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT FBEN_CFIC.CONTACORRENTE FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT FBEN_CFIC.DV FROM SFN_CONTAFIN FBEN_CFIN, SFN_CONTAFIN_COMPLEMENTO FBEN_CFIC WHERE FBEN_CFIN.BENEFICIARIO = FBEN.HANDLE AND FBEN_CFIN.HANDLE = FBEN_CFIC.CONTAFINANCEIRA AND FBEN_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FBEN_CFIC.DATAFINAL IS NULL OR FBEN_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FBEN_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  NULL AS EMAIL,\n  '('||FBEN_ENDC.DDD1||') '||FBEN_ENDC.PREFIXO1||'-'||FBEN_ENDC.NUMERO1 AS FONE,\n  '('||FBEN_ENDC.DDDCELULAR||') '||FBEN_ENDC.PREFIXOCELULAR||'-'||FBEN_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  NULL AS FONE_COMERCIAL,\n  FBEN_ENDC.LOGRADOURO AS LOGRADOURO,\n  FBEN_ENDC.NUMERO AS NUMERO,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1) = 1 THEN\n      'DEBITO AUTOMATICO'\n    WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1) = 1 THEN\n      'BOLETO'\n    ELSE\n      (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.BENEFICIARIO = FBEN.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  'F' AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = FBEN_ENDC.ESTADO) AS UF,\n  CBO.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAINICIAL AS DATA_INICIAL_DEBITO_AUT\n,NVL(FAM.HANDLE,0) AS ID_FAMILIA\nFROM\n  SAM_BENEFICIARIO BEN\n  JOIN SAM_FAM ...
#  {'step_name': 'HANDLE_BENEFICIARIO',
#   'sql_code': 'SELECT BEN.HANDLE AS HANDLE_BENEFICIARIO \nFROM   SAM_BENEFICIARIO BEN\nORDER BY 1 DESC'},
#  {'step_name': 'LOTAÇÃO',
#   'sql_code': "SELECT -- DISTINCT \n  'P' AS TIPO_RESPONSAVEL,\n  LPES.HANDLE AS ID_RESP_FINANCEIRO,\n  LPES_ENDC.BAIRRO AS BAIRRO,\n  LPES_ENDC.CEP AS CEP,\n  LPES_MUNENDC.NOME AS CIDADE,\n  LPES.CNPJCPF AS CNPJ_CPF,\n  LPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  LPES.NOME AS CONTRAT_PAGADOR_NOME,\n  LPES.DATASAIDA AS DATA_EXCLUSAO,\n  LPES.DATAENTRADA AS DATA_INCLUSAO,\n  LPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  LPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  LPES_ENDC.DDD1 AS DDD,\n  LPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT LPES_AGE.AGENCIA FROM SFN_AGENCIA LPES_AGE, SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND LPES_CFIC.AGENCIA = LPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT LPES_BAN.CODIGO FROM SFN_BANCO LPES_BAN, SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND LPES_CFIC.BANCO = LPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT LPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT LPES_CFIC.DV FROM SFN_CONTAFIN LPES_CFIN, SFN_CONTAFIN_COMPLEMENTO LPES_CFIC WHERE LPES_CFIN.PESSOA = LPES.HANDLE AND LPES_CFIN.HANDLE = LPES_CFIC.CONTAFINANCEIRA AND LPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( LPES_CFIC.DATAFINAL IS NULL OR LPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(LPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  LPES.EMAIL AS EMAIL,\n  '('||LPES_ENDC.DDD1||') '||LPES_ENDC.PREFIXO1||'-'||LPES_ENDC.NUMERO1 AS FONE,\n  '('||LPES_ENDC.DDDCELULAR||') '||LPES_ENDC.PREFIXOCELULAR||'-'||LPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||LPES_ENDC.DDD1||') '||LPES_ENDC.PREFIXO1||'-'||LPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  LPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  LPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = LPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN LPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN LPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = LPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSDATE AS DW_ALT,\n  CFC.DATAIN ...
#  {'step_name': 'SAM_FAMILIA_TETO_PF',
#   'sql_code': 'SELECT FT.DATAINICIAL AS DATA_INICIAL_TETO_COBRANCA\n      ,FT.DATAFINAL   AS DATA_FINAL_TETO_COBRANCA\n      ,FT.VALORTETOPF AS VALOR_TETO_COBRANCA\nFROM   SAM_FAMILIA_TETO_PF FT \nWHERE  FT.FAMILIA = ?\nAND    FT.HANDLE  = (SELECT MAX(FT1.HANDLE) FROM SAM_FAMILIA_TETO_PF FT1 WHERE FT1.FAMILIA = FT.FAMILIA)'},
#  {'step_name': 'SEM SETOR',
#   'sql_code': "SELECT  NULL AS SETOR_UNIMED,\n        '('||ENDR.DDD1||') '||ENDR.PREFIXO1||'-'||ENDR.NUMERO1 AS TELEFONE\nFROM    SAM_BENEFICIARIO BEN\nLEFT JOIN SAM_ENDERECO ENDR ON BEN.ENDERECORESIDENCIAL = ENDR.HANDLE\nWHERE   BEN.HANDLE = ?"}]

# %%
def convert_to_filename(input_string):
    s = re.sub(r'[^a-zA-Z0-9_\-\.~]', '_', input_string)
    return s.lower()

# %%
##self.export_to_csv()

def save_to_csv(data, filename):
    # Split the string by newlines to get rows
    rows = data.split('\n')
    
    # Split each row by semicolons to get columns
    formatted_data = [row.split(';') for row in rows]
    
    # Output filename
    output_filename = f"{'output'}/{filename}.csv"

    # Write the formatted data to a CSV file
    with open(output_filename, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Column', 'Table'])  # Write header
        writer.writerows(formatted_data)

# %%
for query in list_of_queries:
    print(query['step_name'])
    file_name = convert_to_filename(query['step_name'])
    result = crew.kickoff(inputs=query)
    output = extract_tables_columns.output
    save_to_csv(output.raw, file_name)
    #result_collector.add_result('export_tables_columns',output.raw,file_name)
# Out:
# BENEFICIÁRIO
# BUSCA MICROSIGA
# CONTRATO
# FAMILIA PESSOA RESPONSÁVEL
# FAMILIA TITULAR RESPONSÁVEL
# HANDLE_BENEFICIARIO
# LOTAÇÃO
# 2024-08-28 13:51:22,146 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2024-08-28 13:51:24,772 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2024-08-28 13:51:27,744 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2024-08-28 13:51:30,404 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2024-08-28 13:51:33,169 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2024-08-28 13:51:35,831 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2024-08-28 13:51:38,453 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2024-08-28 13:51:41,156 - 139766624456704 - before_sleep.py-before_sleep:65 - WARNING: Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[583], line 4
#       2 print(query['step_name'])
#       3 file_name = convert_to_filename(query['step_name'])
# ----> 4 result = crew.kickoff(inputs=query)
#       5 output = extract_tables_columns.output
#       6 save_to_csv(output.raw, file_name)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/crew.py:469, in Crew.kickoff(self, inputs)
#     466 metrics: List[UsageMetrics] = []
#     468 if self.process == Process.sequential:
# --> 469     result = self._run_sequential_process()
#     470 elif self.process == Process.hierarchical:
#     471     result = self._run_hierarchical_process()
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/crew.py:577, in Crew._run_sequential_process(self)
#     575 def _run_sequential_process(self) -> CrewOutput:
#     576     """Executes tasks sequentially and returns the final output."""
# --> 577     return self._execute_tasks(self.tasks)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/crew.py:665, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     662     futures.clear()
#     664 context = self._get_context(task, task_outputs)
# --> 665 task_output = task.execute_sync(
#     666     agent=agent_to_use,
#     667     context=context,
#     668     tools=agent_to_use.tools,
#     669 )
#     670 task_outputs = [task_output]
#     671 self._process_task_result(task, task_output)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/task.py:180, in Task.execute_sync(self, agent, context, tools)
#     173 def execute_sync(
#     174     self,
#     175     agent: Optional[BaseAgent] = None,
#     176     context: Optional[str] = None,
#     177     tools: Optional[List[Any]] = None,
#     178 ) -> TaskOutput:
#     179     """Execute the task synchronously."""
# --> 180     return self._execute_core(agent, context, tools)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/task.py:234, in Task._execute_core(self, agent, context, tools)
#     231 self.prompt_context = context
#     232 tools = tools or self.tools or []
# --> 234 result = agent.execute_task(
#     235     task=self,
#     236     context=context,
#     237     tools=tools,
#     238 )
#     240 pydantic_output, json_output = self._export_output(result)
#     242 task_output = TaskOutput(
#     243     description=self.description,
#     244     raw=result,
#    (...)
#     248     output_format=self._get_output_format(),
#     249 )
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/agent.py:203, in Agent.execute_task(self, task, context, tools)
#     200     task_prompt = self._use_trained_data(task_prompt=task_prompt)
#     202 try:
# --> 203     result = self.agent_executor.invoke(
#     204         {
#     205             "input": task_prompt,
#     206             "tool_names": self.agent_executor.tools_names,
#     207             "tools": self.agent_executor.tools_description,
#     208         }
#     209     )["output"]
#     210 except Exception as e:
#     211     self._times_executed += 1
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain/chains/base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain/chains/base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/agents/executor.py:83, in CrewAgentExecutor._call(self, inputs, run_manager)
#      81 while self._should_continue(self.iterations, time_elapsed):
#      82     if not self.request_within_rpm_limit or self.request_within_rpm_limit():
# ---> 83         next_step_output = self._take_next_step(
#      84             name_to_tool_map,
#      85             color_mapping,
#      86             inputs,
#      87             intermediate_steps,
#      88             run_manager=run_manager,
#      89         )
#      91         if self.step_callback:
#      92             self.step_callback(next_step_output)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain/agents/agent.py:1314, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1305 def _take_next_step(
#    1306     self,
#    1307     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1311     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1312 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1313     return self._consume_next_step(
# -> 1314         [
#    1315             a
#    1316             for a in self._iter_next_step(
#    1317                 name_to_tool_map,
#    1318                 color_mapping,
#    1319                 inputs,
#    1320                 intermediate_steps,
#    1321                 run_manager,
#    1322             )
#    1323         ]
#    1324     )
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain/agents/agent.py:1314, in <listcomp>(.0)
#    1305 def _take_next_step(
#    1306     self,
#    1307     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1311     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1312 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1313     return self._consume_next_step(
# -> 1314         [
#    1315             a
#    1316             for a in self._iter_next_step(
#    1317                 name_to_tool_map,
#    1318                 color_mapping,
#    1319                 inputs,
#    1320                 intermediate_steps,
#    1321                 run_manager,
#    1322             )
#    1323         ]
#    1324     )
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/crewai/agents/executor.py:147, in CrewAgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     144     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#     146     # Call the LLM to see what to do.
# --> 147     output = self.agent.plan(
#     148         intermediate_steps,
#     149         callbacks=run_manager.get_child() if run_manager else None,
#     150         **inputs,
#     151     )
#     153 except OutputParserException as e:
#     154     if isinstance(self.handle_parsing_errors, bool):
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain/agents/agent.py:461, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     453 final_output: Any = None
#     454 if self.stream_runnable:
#     455     # Use streaming to make sure that the underlying LLM is invoked in a
#     456     # streaming
#    (...)
#     459     # Because the response from the plan is not a generator, we need to
#     460     # accumulate the output into final output and return that.
# --> 461     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     462         if final_output is None:
#     463             final_output = chunk
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:3262, in RunnableSequence.stream(self, input, config, **kwargs)
#    3256 def stream(
#    3257     self,
#    3258     input: Input,
#    3259     config: Optional[RunnableConfig] = None,
#    3260     **kwargs: Optional[Any],
#    3261 ) -> Iterator[Output]:
# -> 3262     yield from self.transform(iter([input]), config, **kwargs)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:3249, in RunnableSequence.transform(self, input, config, **kwargs)
#    3243 def transform(
#    3244     self,
#    3245     input: Iterator[Input],
#    3246     config: Optional[RunnableConfig] = None,
#    3247     **kwargs: Optional[Any],
#    3248 ) -> Iterator[Output]:
# -> 3249     yield from self._transform_stream_with_config(
#    3250         input,
#    3251         self._transform,
#    3252         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3253         **kwargs,
#    3254     )
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:2054, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2052 try:
#    2053     while True:
# -> 2054         chunk: Output = context.run(next, iterator)  # type: ignore
#    2055         yield chunk
#    2056         if final_output_supported:
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:3211, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3208     else:
#    3209         final_pipeline = step.transform(final_pipeline, config)
# -> 3211 for output in final_pipeline:
#    3212     yield output
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:1272, in Runnable.transform(self, input, config, **kwargs)
#    1269 final: Input
#    1270 got_first_val = False
# -> 1272 for ichunk in input:
#    1273     # The default implementation of transform is to buffer input and
#    1274     # then call stream.
#    1275     # It'll attempt to gather all input into a single chunk using
#    1276     # the `+` operator.
#    1277     # If the input is not addable, then we'll assume that we can
#    1278     # only operate on the last chunk,
#    1279     # and we'll iterate until we get to the last chunk.
#    1280     if not got_first_val:
#    1281         final = ichunk
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:5301, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5295 def transform(
#    5296     self,
#    5297     input: Iterator[Input],
#    5298     config: Optional[RunnableConfig] = None,
#    5299     **kwargs: Any,
#    5300 ) -> Iterator[Output]:
# -> 5301     yield from self.bound.transform(
#    5302         input,
#    5303         self._merge_configs(config),
#    5304         **{**self.kwargs, **kwargs},
#    5305     )
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1287             final = ichunk
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:410, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     403 except BaseException as e:
#     404     run_manager.on_llm_error(
#     405         e,
#     406         response=LLMResult(
#     407             generations=[[generation]] if generation else []
#     408         ),
#     409     )
# --> 410     raise e
#     411 else:
#     412     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:390, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     387     self.rate_limiter.acquire(blocking=True)
#     389 try:
# --> 390     for chunk in self._stream(messages, stop=stop, **kwargs):
#     391         if chunk.message.id is None:
#     392             chunk.message.id = f"run-{run_manager.run_id}"
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:1056, in ChatGoogleGenerativeAI._stream(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, **kwargs)
#    1041 request = self._prepare_request(
#    1042     messages,
#    1043     stop=stop,
#    (...)
#    1048     generation_config=generation_config,
#    1049 )
#    1050 response: GenerateContentResponse = _chat_with_retry(
#    1051     request=request,
#    1052     generation_method=self.client.stream_generate_content,
#    1053     **kwargs,
#    1054     metadata=self.default_metadata,
#    1055 )
# -> 1056 for chunk in response:
#    1057     _chat_result = _response_to_result(chunk, stream=True)
#    1058     gen = cast(ChatGenerationChunk, _chat_result.generations[0])
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:116, in _StreamingResponseIterator.__next__(self)
#     114         del self._stored_first_result
#     115         return result
# --> 116     return next(self._wrapped)
#     117 except grpc.RpcError as exc:
#     118     # If the stream has already returned data, we cannot recover here.
#     119     raise exceptions.from_grpc_error(exc) from exc
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/grpc/_channel.py:543, in _Rendezvous.__next__(self)
#     542 def __next__(self):
# --> 543     return self._next()
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/grpc/_channel.py:960, in _MultiThreadedRendezvous._next(self)
#     954 def _response_ready():
#     955     return self._state.response is not None or (
#     956         cygrpc.OperationType.receive_message not in self._state.due
#     957         and self._state.code is not None
#     958     )
# --> 960 _common.wait(self._state.condition.wait, _response_ready)
#     961 if self._state.response is not None:
#     962     response = self._state.response
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/grpc/_common.py:156, in wait(wait_fn, wait_complete_fn, timeout, spin_cb)
#     154 if timeout is None:
#     155     while not wait_complete_fn():
# --> 156         _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#     157 else:
#     158     end = time.time() + timeout
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/grpc/_common.py:116, in _wait_once(wait_fn, timeout, spin_cb)
#     111 def _wait_once(
#     112     wait_fn: Callable[..., bool],
#     113     timeout: float,
#     114     spin_cb: Optional[Callable[[], None]],
#     115 ):
# --> 116     wait_fn(timeout=timeout)
#     117     if spin_cb is not None:
#     118         spin_cb()
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
output = extract_tables_columns.output

# %%
output.raw
# Out:
# 'SETOR_UNIMED;SAM_BENEFICIARIO\nENDERECORESIDENCIAL;SAM_BENEFICIARIO\nHANDLE;SAM_BENEFICIARIO\nDDD1;SAM_ENDERECO\nPREFIXO1;SAM_ENDERECO\nNUMERO1;SAM_ENDERECO\nTELEFONE;SAM_ENDERECO'

# %%
#result = crew.kickoff(inputs=list_of_queries)
# Out:
# Adding result for task: extract_tables_columns, step: my_step_name
# Exporting result to output/my_step_name.csv

# %%
#result = crew.kickoff_for_each(inputs=list_of_queries)

# %%
result_collector.results[3]
# Out:
# {'task': 'extract_tables_columns',
#  'result': TaskOutput(description="\nAnalyse SELECT --DISTINCT\n  'P' AS TIPO_RESPONSAVEL,\n  FPES.HANDLE AS ID_RESP_FINANCEIRO,\n  FPES_ENDC.BAIRRO AS BAIRRO,\n  FPES_ENDC.CEP AS CEP,\n  FPES_MUNENDC.NOME AS CIDADE,\n  FPES.CNPJCPF AS CNPJ_CPF,\n  FPES_ENDC.COMPLEMENTO AS COMPLEMENTO,\n  FPES.NOME AS CONTRAT_PAGADOR_NOME,\n  FPES.DATASAIDA AS DATA_EXCLUSAO,\n  FPES.DATAENTRADA AS DATA_INCLUSAO,\n  FPES.DATANASCIMENTO AS DATA_NASCIMENTO,\n  FPES_ENDC.DDDCELULAR AS DDD_CELULAR,\n  FPES_ENDC.DDD1 AS DDD,\n  FPES_ENDC.DDD1 AS DDD_COMERCIAL,\n  CASE\n    WHEN (SELECT 1 FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) = 1 THEN 'S' \n    ELSE 'N'\n  END AS DEBITO_AUT,\n  (SELECT FPES_AGE.AGENCIA FROM SFN_AGENCIA FPES_AGE, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.AGENCIA = FPES_AGE.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_AGENCIA,\n  (SELECT FPES_BAN.CODIGO FROM SFN_BANCO FPES_BAN, SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND FPES_CFIC.BANCO = FPES_BAN.HANDLE AND ROWNUM = 1) AS DEBITO_AUT_BANCO,\n  (SELECT FPES_CFIC.CONTACORRENTE FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_CONTA,\n  (SELECT FPES_CFIC.DV FROM SFN_CONTAFIN FPES_CFIN, SFN_CONTAFIN_COMPLEMENTO FPES_CFIC WHERE FPES_CFIN.PESSOA = FPES.HANDLE AND FPES_CFIN.HANDLE = FPES_CFIC.CONTAFINANCEIRA AND FPES_CFIC.DATAINICIAL <= TRUNC(SYSDATE) AND ( FPES_CFIC.DATAFINAL IS NULL OR FPES_CFIC.DATAFINAL >= TRUNC(SYSDATE) ) AND NVL(FPES_CFIC.CONTACORRENTE, '0') <> '0' AND ROWNUM = 1) AS DEBITO_AUT_DIGITO,\n  FPES.EMAIL AS EMAIL,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE,\n  '('||FPES_ENDC.DDDCELULAR||') '||FPES_ENDC.PREFIXOCELULAR||'-'||FPES_ENDC.NUMEROCELULAR AS FONE_CELULAR,\n  '('||FPES_ENDC.DDD1||') '||FPES_ENDC.PREFIXO1||'-'||FPES_ENDC.NUMERO1 AS FONE_COMERCIAL,\n  FPES_ENDC.LOGRADOURO AS LOGRADOURO,\n  FPES_ENDC.NUMERO AS NUMERO,\n  CASE\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_COMPLEMENTO COM, SFN_CONTAFIN FIN WHERE NVL(COM.CONTACORRENTE, '0') <> '0' AND COM.DATAINICIAL <= TRUNC(SYSDATE) AND ( COM.DATAFINAL IS NULL OR COM.DATAFINAL >= TRUNC(SYSDATE) ) AND COM.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'DEBITO AUTOMATICO'\n     WHEN (SELECT 1 FROM SFN_CONTAFIN_TIPODOCUMENTO DOC, SFN_CONTAFIN FIN WHERE DOC.CONTAFINANCEIRA = FIN.HANDLE AND FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1) = 1 THEN\n       'BOLETO'\n     ELSE\n       (SELECT DECODE(FIN.TABGERACAOREC, 1, 'CONTA CORRENTE', 2, 'CARTAO CREDITO', 3, 'BOLETO') FROM SFN_CONTAFIN FIN WHERE FIN.PESSOA = FPES.HANDLE AND ROWNUM = 1)\n  END AS TIPO_COBRANCA,\n  CASE WHEN FPES.TABFISICAJURIDICA = 1 THEN 'F' WHEN FPES.TABFISICAJURIDICA = 2 THEN 'J' END AS TIPO_PESSOA,\n  (SELECT SIGLA FROM ESTADOS WHERE HANDLE = FPES_ENDC.ESTADO) AS UF,\n  RAMATI.DESCRICAO AS RAMO_DE_ATIVIDADE,\n  TIPDOC.DESCRICAO AS TIPO_DOCUMENTO,\n  SYSDATE AS DW_INC,\n  SYSD ...

# %%
teste2 = teste['result']

# %%
teste2.csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 teste2.csv
#
# File ~/repos/llm-agents-pentaho-mapping/.venv/lib/python3.10/site-packages/pydantic/main.py:828, in BaseModel.__getattr__(self, item)
#     825     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     826 else:
#     827     # this is the current error
# --> 828     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'TaskOutput' object has no attribute 'csv'
